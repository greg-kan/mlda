# %%
import numpy as np
import pandas as pd
#import sqlite3 as sq
import re
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
def label_cleaner(text):
        
    text = re.sub( r'ЖАЛОБА: на ', '', text) # Убрать из темы словосочетания 'ЖАЛОБА: на ',
    text = re.sub( r'ЖАЛОБА: ', '', text) # 'ЖАЛОБА: ',
    text = re.sub( r'Жалоба на ', '', text) # 'Жалоба на ',
    text = re.sub( r'Жалобы на ', '', text) # 'Жалобы на '
    
    text = str.strip(text.lower()) #Переводим в нижний регистр и убираем пробелы
    return  text

def text_cleaner(text):
    text = text.lower() # приведение в lowercase,
    
    text = re.sub( r'https?://[\S]+', ' url ', text) # замена интернет ссылок
    text = re.sub( r'[\w\./]+\.[a-z]+', ' url ', text) 
 
    # text = re.sub( r'\d+[-/\.]\d+[-/\.]\d+', ' date ', text) # замена даты и времени
    # text = re.sub( r'\d+ ?гг?', ' date ', text) 
    # text = re.sub( r'\d+:\d+(:\d+)?', ' time ', text) 

    # text = re.sub( r'@\w+', ' tname ', text ) # замена имён twiter
    # text = re.sub( r'#\w+', ' htag ', text ) # замена хештегов

    text = re.sub( r'<[^>]*>', ' ', text) # удаление html тагов
    text = re.sub( r'[\W]+', ' ', text ) # удаление не словарных символов

    stemmer = SnowballStemmer("russian")
    singles = [stemmer.stem(word) for word in text.split()]
    text = ' '.join(singles)

    # stw = ['в', 'по', 'на', 'из', 'и', 'или', 'не', 'но', 'за', 'над', 'под', 'то',
    #        'a', 'at', 'on', 'of', 'and', 'or', 'in', 'for', 'at' ]
    # remove = r'\b('+'|'.join(stw)+')\b'
    # text = re.sub(remove,' ', text)
    
    # text = re.sub( r'\b\w\b', ' ', text ) # удаление отдельно стоящих букв

    text = re.sub( r'\b\d+\b', ' digit ', text ) # замена цифр 

    return  text

def train_test_split( data, validation_split = 0.2):
    dict_data = data.to_dict('list')
    sz = len(dict_data['TOPIC'])
    indices = np.arange(sz)
    np.random.shuffle(indices)

    X = [ dict_data['DESCRIPTION'][i] for i in indices ]
    Y = [ dict_data['TOPIC'][i] for i in indices ]
    nb_validation_samples = int( validation_split * sz )

    return { 
        'train': { 'x': X[:-nb_validation_samples], 'y': Y[:-nb_validation_samples]  },
        'test': { 'x': X[-nb_validation_samples:], 'y': Y[-nb_validation_samples:]  }
    }

# %%
# Загружаем данные
#raw_data = pd.read_csv('complaints.csv', header = 0, sep = ';')
raw_data = pd.read_excel('complaints.xlsx', sheet_name='complaints', index_col=None)
#raw_data.info()
raw_data.head()
# Out:
#    ISSUENUM                             TOPIC  \
# 0    105578  ЖАЛОБА: на корреспонденцию банка
# 1    105582  ЖАЛОБА: на корреспонденцию банка
# 2    105604           ЖАЛОБА: на обслуживание
# 3    105614           ЖАЛОБА: на обслуживание
# 4    105632  ЖАЛОБА: на корреспонденцию банка
#
#                            UNDER_TOPIC       REPORTER    ASSIGNEE  \
# 0            Cмс по предложениям Xsell     aoryntaeva  akalabaeva
# 1            Cмс по предложениям Xsell      atusipova  akalabaeva
# 2                                  NaN     azhalgaeva    zissayev
# 3  ЖАЛОБА: на обслуживание Call-center     aamankeldi    zissayev
# 4            Cмс по предложениям Xsell  aabdykadyrova    zissayev
#
#          CREATOR STATUS_ISSUE             CREATED             UPDATED  \
# 0     aoryntaeva      Закрыта 2017-12-12 06:47:45 2017-12-12 12:02:50
# 1      atusipova      Закрыта 2017-12-12 08:34:06 2017-12-12 15:41:16
# 2     azhalgaeva      Закрыта 2017-12-12 09:27:28 2017-12-21 09:10:29
# 3     aamankeldi      Закрыта 2017-12-12 09:48:57 2018-01-04 08:52:08
# 4  aabdykadyrova      Закрыта 2017-12-12 10:34:31 2017-12-14 09:57:35
#
#        RESOLUTIONDATE  ...                     FIO_CLIENT           IIN  \
# 0 2017-12-12 12:02:50  ...   АҚЖИГИТОВ БЕЙБІТ КЕНЖЕБАЙҰЛЫ  910429301833
# 1 2017-12-12 12:05:45  ...      Тверитинова Анна Егоровна  761123400947
# 2 2017-12-14 16:05:54  ...  Дарипова Айгуль Сабыргалиевна  810420403003
# 3 2017-12-14 16:06:10  ...      Белова Викторовна Татьяна  860714450805
# 4 2017-12-14 09:57:35  ...   Онгарбаева Нурсакип Окановна  580209400606
#
#   TEXT_CONTRACT_NUMBER      PHONE_NUMBER INF_CLIENT_RESPONDING  \
# 0                    0        7776121291                   NaN
# 1           3708168706    87078452136 \t                   NaN
# 2                    0        7292250739             Не дозвон
# 3           3712793921        7777813881             Не дозвон
# 4           3647319049  8 775 229 15 13              Не дозвон
#
#                                      INCIDENT_REGION  \
# 0                                                  0
# 1                                                  0
# 2   Мангистауская область,Бейнеу,  ул. Ерконай, д. 1
# 3                                             Алматы
# 4                                    Алматинская обл
#
#               INCIDENT_RESOLVED FIO_GUILT_WORK AUTHOR_REGION  \
# 0  Не требует создания проблемы            NaN        Алматы
# 1  Не требует создания проблемы            NaN           NaN
# 2  Не требует создания проблемы            NaN         Актау
# 3  Не требует создания проблемы  dtungyshbaeva        Алматы
# 4  Не требует создания проблемы            NaN        Алматы
#
#   AUTHOR_SUBDIVISIONS
# 0         Call-center
# 1         Call-center
# 2         Call-center
# 3         Call-center
# 4         Call-center
#
# [5 rows x 21 columns]

# %%
print("Размерность до препроцессинга: ", raw_data.shape)

#Preprocessing
valuable_columns = ["TOPIC", "DESCRIPTION"]
raw_data = raw_data[valuable_columns]
raw_data = raw_data.dropna(subset=['TOPIC']) # Удаляем строки с пустыми значениями в столбце 'TOPIC'

print("Размерность после препроцессинга", raw_data.shape)

# Отберем только строки, содержащие жалобы, в которых столбец 'TOPIC' содержит различные сочетания слова "жалоба"
raw_data = raw_data[(raw_data.TOPIC.str.contains("ЖАЛОБА: ") |
                     raw_data.TOPIC.str.contains("Жалоба на ") |
                     raw_data.TOPIC.str.contains("Жалобы на "))] #, na=False

print("Размерность данных с Жалобами", raw_data.shape)

raw_data["TOPIC"] = [ label_cleaner(t) for t in raw_data["TOPIC"]] # Почистим метки от "мусора"

print("\tКоличество категорий:", len(set(raw_data["TOPIC"])))
print("\tМножество категорий:")
print(set(raw_data["TOPIC"]))
# Out:
# Размерность до препроцессинга:  (22840, 21)
# Размерность после препроцессинга (22805, 2)
# Размерность данных с Жалобами (19415, 2)
# 	Количество категорий: 9
# 	Множество категорий:
# {'корреспонденцию банка', 'обслуживание', 'карточные продукты', 'го/филиал/отделения/микроофисы/тт', 'не согласие с условиями договора, %%, задолженностью, штрафами, тарифами и комиссиями', 'услугу "страховку"', 'услугу "хранитель"', 'услугу "защита семьи"', 'обслуживание в терминалах'}

# %%
#Разделяем данные на Тренировочную и Тестовую выборки
D = train_test_split(raw_data, 0.3)

print("\tРазмер тестовой выборки:", len(D['test'] ['y']))
print("\tРазмер тренировочной выборки:", len(D['train'] ['y']))
print("\tОбщий размер данных:", len(D['test'] ['y']) + len(D['train'] ['y']))
# Out:
# 	Размер тестовой выборки: 5824
# 	Размер тренировочной выборки: 13591
# 	Общий размер данных: 19415

# %%
print("[i] Обучение классификатора...")

    # text_clf = Pipeline([
    #                ('hashvect', HashingVectorizer() ),
    #                ('tfidf', TfidfTransformer(use_idf=False )),
    #                ('clf', SGDClassifier(loss='hinge')),
    #                ])
    #
    # text_clf = Pipeline([
    #                ('covect', CountVectorizer() ),
    #                ('tfidf', TfidfTransformer(preprocessor=text_cleaner,use_idf=False )),
    #                ('clf', SGDClassifier(loss='hinge')),
    #                ])


text_clf = Pipeline([
                ('tfidf', TfidfVectorizer()),
                ('clf', SGDClassifier(loss='hinge')),
                ])

text_clf.fit(D['train']['x'], D['train']['y'])

print("[i] Обучение завершено!")
# Out:
# [i] Обучение классификатора...
# D:\tools\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [i] Обучение завершено!

# %%
#Testing and checking results
print("[i] Тестируем...")

predicted = text_clf.predict( D['train']['x'] )
print("\taccuracy train: ", accuracy_score(  D['train']['y'] , predicted) )
    
predicted = text_clf.predict( D['test']['x'] )
print("\taccuracy test: ", accuracy_score(  D['test']['y'] , predicted) )
# Out:
# [i] Тестируем...
# 	accuracy train:  0.9156059156794938
# 	accuracy test:  0.8597184065934066

# %%
frameTrain = pd.DataFrame({'cathegory': D['train']['y'], 'content': D['train']['x']})

# %%
frameTrain.head()
# Out:
#                                            cathegory  \
# 0                                       обслуживание
# 1  не согласие с условиями договора, %%, задолжен...
# 2                                       обслуживание
# 3                              корреспонденцию банка
# 4                                       обслуживание
#
#                                              content
# 0  Клиент жалуется на обслуживание в колл-центра....
# 1  ДД!\n условия кредита, на сайте было указанно ...
# 2  клиент жалуется что в раннем оформлении не пре...
# 3  Клиент Недосеикин Сергей Лионидович просит \nч...
# 4  Внешние запросы               \n\nФИО: Казанга...

# %%
print(frameTrain.shape)
# Out:
# (13591, 2)

# %%
frameTrain['predicted'] = text_clf.predict( D['train']['x'] ).tolist()

# %%
print(frameTrain.shape)
# Out:
# (13591, 3)

# %%
frameTrain.head(50)
# Out:
#                                             cathegory  \
# 0                                        обслуживание
# 1   не согласие с условиями договора, %%, задолжен...
# 2                                        обслуживание
# 3                               корреспонденцию банка
# 4                                        обслуживание
# 5                                        обслуживание
# 6                                        обслуживание
# 7                                        обслуживание
# 8   не согласие с условиями договора, %%, задолжен...
# 9                                        обслуживание
# 10                              корреспонденцию банка
# 11                              корреспонденцию банка
# 12  не согласие с условиями договора, %%, задолжен...
# 13                              корреспонденцию банка
# 14                              корреспонденцию банка
# 15                              корреспонденцию банка
# 16                                       обслуживание
# 17                          обслуживание в терминалах
# 18                                       обслуживание
# 19                              корреспонденцию банка
# 20                              корреспонденцию банка
# 21                              корреспонденцию банка
# 22                              корреспонденцию банка
# 23                                       обслуживание
# 24                  го/филиал/отделения/микроофисы/тт
# 25                              корреспонденцию банка
# 26                                       обслуживание
# 27                                       обслуживание
# 28                                 услугу "страховку"
# 29                                       обслуживание
# 30                                 услугу "страховку"
# 31                              корреспонденцию банка
# 32                                       обслуживание
# 33                              корреспонденцию банка
# 34                                       обслуживание
# 35                              корреспонденцию банка
# 36                                 услугу "страховку"
# 37  не согласие с условиями договора, %%, задолжен...
# 38                              корреспонденцию банка
# 39                              корреспонденцию банка
# 40                              корреспонденцию банка
# 41                              корреспонденцию банка
# 42                                       обслуживание
# 43                                       обслуживание
# 44                              корреспонденцию банка
# 45                                       обслуживание
# 46                                       обслуживание
# 47                                       обслуживание
# 48                                 услугу "страховку"
# 49                                       обслуживание
#
#                                               content  \
# 0   Клиент жалуется на обслуживание в колл-центра....
# 1   ДД!\n условия кредита, на сайте было указанно ...
# 2   клиент жалуется что в раннем оформлении не пре...
# 3   Клиент Недосеикин Сергей Лионидович просит \nч...
# 4   Внешние запросы               \n\nФИО: Казанга...
# 5    \n\n \n\nВнешние запросы\n\n \n\nФИО: Нет дан...
# 6   ДД! Клиент Кузнецова Ирина Евгеньевна жалуется...
# 7   Менеджер неверно предоставил информацию, "офор...
# 8   Добрый день!\nКлиент не согласен с суммой кото...
# 9   клиент жалуеться что оплачивал все вовремя  и ...
# 10  Клиент жалуется что ему ппиходят смс уведомлен...
# 11  Клиент жалуется что часто поступают смс уведом...
# 12  Клиент жалуется, оплатил кредит через приложен...
# 13  Клиент просит не беспокоить с смс  уведомления...
# 14  Здравствуйте. Владельцу номера - 87014637763 о...
# 15  Клиент Арайлым Тлеужановна сообщила что ей зво...
# 16  Клиент обратился 14.04.2017 в отделение банка,...
# 17  клиент пожаловался на то что терминал не выдал...
# 18  Добрый день! Клиент оформлял в нашем банке тов...
# 19  Клиент жалуется  на звонки, до оплаты есть вре...
# 20  Клиент жалуется на то что не получает смс увед...
# 21  клиент хочет чтобы ему отправляли смс уведомле...
# 22  Клиенту приходит смс уведомление код подтвержд...
# 23  Добрый день! Клиент просит принять жалобу на н...
# 24  Клиент Сатылганова Бубижан Киргабаковна жалует...
# 25  Клиент просит больше не беспокоить его звонкам...
# 26  Альжанов Санжар Оразгалиевич утверждает, что п...
# 27  Клиент жалуется на обслуживание, сотрудник при...
# 28  КК предоставил некорректную информацию сказав,...
# 29  Добрый день! Клиент выражает не довольство по ...
# 30  По словам клиента: менеджер не проконсультиров...
# 31  на номер 87163122091 звонят по поводу кредита ...
# 32  Добрый день !  клиент жалуется что менеджер не...
# 33  ДД! Клиенту приходят смс на имя Асель Айдархан...
# 34  Клиент отказывается оплачивать сумму последнег...
# 35  Клиент хочет чтобы ее уведомляли об ежемесячно...
# 36  Клиент утверждает что кредитный консультант не...
# 37  Клиент ранее обращался чтоб сняли арест,арест ...
# 38  Клиент ТУРКМЕНБАЕВ КУАТ АХМЕДҰЛЫ хочет получат...
# 39  клиент просит не звонить ему на дом номер 57-3...
# 40  Здравствуйте. Клиенту сегодня звонили со сторо...
# 41  клиент утверждает что каждый день  звонят с БХ...
# 42  Сабырбаева Фатима Зайтышовна   клиент 08/09/20...
# 43  Описание: Клиент жалуется на то, что не может ...
# 44  Абуова Жанна Анарбековна просит не звонить,кли...
# 45  Клиент не знала насчёт страхования, менеджер у...
# 46  Клиент жалуется на менеджер который по словам ...
# 47  Добрый день! Клиент жалуется на то, что ему зв...
# 48  По словам клиента: менджер навязал услугу Фин....
# 49  Доброго времени суток! Клиент жалуется на обсл...
#
#                                             predicted
# 0                                        обслуживание
# 1                                        обслуживание
# 2                                        обслуживание
# 3                               корреспонденцию банка
# 4                                        обслуживание
# 5                                        обслуживание
# 6                                        обслуживание
# 7                                        обслуживание
# 8   не согласие с условиями договора, %%, задолжен...
# 9                                        обслуживание
# 10                              корреспонденцию банка
# 11                              корреспонденцию банка
# 12  не согласие с условиями договора, %%, задолжен...
# 13                              корреспонденцию банка
# 14                              корреспонденцию банка
# 15                                       обслуживание
# 16                                       обслуживание
# 17                          обслуживание в терминалах
# 18                                       обслуживание
# 19                              корреспонденцию банка
# 20                              корреспонденцию банка
# 21                              корреспонденцию банка
# 22                              корреспонденцию банка
# 23                                       обслуживание
# 24                                       обслуживание
# 25                              корреспонденцию банка
# 26                                       обслуживание
# 27                                       обслуживание
# 28                                 услугу "страховку"
# 29                                       обслуживание
# 30                                 услугу "страховку"
# 31                              корреспонденцию банка
# 32                                       обслуживание
# 33                              корреспонденцию банка
# 34                                       обслуживание
# 35                              корреспонденцию банка
# 36                                 услугу "страховку"
# 37  не согласие с условиями договора, %%, задолжен...
# 38                              корреспонденцию банка
# 39                              корреспонденцию банка
# 40                              корреспонденцию банка
# 41                              корреспонденцию банка
# 42                                       обслуживание
# 43                                       обслуживание
# 44                              корреспонденцию банка
# 45                                       обслуживание
# 46                                       обслуживание
# 47                                       обслуживание
# 48                                 услугу "страховку"
# 49                                       обслуживание

# %%
frameTrain.to_excel('complaints_train.xlsx', sheet_name='complaints_train')

# %%
frameTest = pd.DataFrame({'cathegory': D['test']['y'], 'content': D['test']['x']})

# %%
print(frameTest.shape)
# Out:
# (5824, 2)

# %%
frameTest['predicted'] = text_clf.predict( D['test']['x'] ).tolist()

# %%
print(frameTest.shape)
# Out:
# (5824, 3)

# %%
frameTest.head(50)
# Out:
#                                             cathegory  \
# 0                               корреспонденцию банка
# 1                               корреспонденцию банка
# 2                               корреспонденцию банка
# 3                                        обслуживание
# 4                                        обслуживание
# 5                                        обслуживание
# 6                                        обслуживание
# 7                                        обслуживание
# 8                                        обслуживание
# 9                                        обслуживание
# 10                                       обслуживание
# 11                                 услугу "страховку"
# 12                                       обслуживание
# 13                                       обслуживание
# 14                          обслуживание в терминалах
# 15                              корреспонденцию банка
# 16                                       обслуживание
# 17                                       обслуживание
# 18                              корреспонденцию банка
# 19                              корреспонденцию банка
# 20                              корреспонденцию банка
# 21                              корреспонденцию банка
# 22                              корреспонденцию банка
# 23                                       обслуживание
# 24                                       обслуживание
# 25                                 услугу "хранитель"
# 26                                       обслуживание
# 27                                       обслуживание
# 28                                       обслуживание
# 29                                 услугу "страховку"
# 30                          обслуживание в терминалах
# 31                                       обслуживание
# 32                              корреспонденцию банка
# 33  не согласие с условиями договора, %%, задолжен...
# 34                                       обслуживание
# 35                                       обслуживание
# 36                                       обслуживание
# 37                                       обслуживание
# 38  не согласие с условиями договора, %%, задолжен...
# 39                              корреспонденцию банка
# 40                              корреспонденцию банка
# 41                              корреспонденцию банка
# 42                                       обслуживание
# 43                                       обслуживание
# 44                              корреспонденцию банка
# 45                              корреспонденцию банка
# 46                              корреспонденцию банка
# 47                              корреспонденцию банка
# 48                                       обслуживание
# 49                              корреспонденцию банка
#
#                                               content  \
# 0   Руководитель мед центра "Саумет"  Тохсеитова С...
# 1   ДД! Клиент жалуется на то, что ему приходят см...
# 2   \n\nЗвонят с банка третьему лицу. Просят Макее...
# 3   Токмухамбетова Алмагуль Сериковна  подала жало...
# 4   Кайырлы кун ! Клиент шагым калдырды. Менеджер ...
# 5   Клиент жалуется на менеджера за предоставленну...
# 6   Клиент посит уточнить почему. Менеджер просит ...
# 7   Добрый день, Клиент жалуется на то что при офо...
# 8   Дд! У клиента был карточный продукт, однако по...
# 9   Клиент жалуется на малое количество сотруднико...
# 10  Клиент Садиров Нуржан Абаевич на сотрудника Ба...
# 11  Добрый день! Клиент не согласен с условиями ст...
# 12  Доброго времени суток! Клиент Асанова Гульмира...
# 13  Описание:Жалоба на оператора: Клиент спросил у...
# 14  ДД! \nКлиент жалуется на то, что терминал в г....
# 15  клиент просит не отправлять смс - уведомления ...
# 16  По словам клента: менеджер не предложил страхз...
# 17  Клиент звонил в колл центр чтобы уточнить задо...
# 18  Звонят с нашего банка на этот номер 8701211056...
# 19  здравствуйте. клиенту приходят смс и поступают...
# 20  Клиент \nОРАЗБАЕВА АЖАР АБДИБЕКОВНА просит, чт...
# 21  Добрый день! Алексей возмущен тем что , и ране...
# 22  клиент жалуется что он полностью закрыл кредит...
# 23  Клиент Рамазан Мирзагалиевич жалуется на обслу...
# 24  Клиент желает получить справку о том, что у не...
# 25   \n\n \n\nВнешние запросы\n\n \n\nФИО: Жалкасо...
# 26  Добрый день!Клиент жалуется на неправильную ко...
# 27  Клиент Темирбаев Асхат Даукенович звонил в кол...
# 28  Описание:  Клиент жалуется на МРК\КК,  при офо...
# 29  Клиент утверждает что кредитный консультант не...
# 30  клиент утверждает что оплатил через терминал Б...
# 31  По словам клиента оператор грубо обращался с к...
# 32  клиент просит чтобы его номера убрали с базы и...
# 33  Описание: Клиент позвонил для уточнения остатк...
# 34  Виновный сотрудник: Бакытгуль, 17.00, 87078584...
# 35  з-к Худайкулиева Злаудиновна Дилярам кд 371389...
# 36  ДД!\nКлиент оформил карту DOS WI 13/06/2018, п...
# 37  клиентка жалуется на менеджера который не пред...
# 38  Описание: Клиент просит чтобы сняли с его счет...
# 39  Дочь владельца данного номера 87054159832 жела...
# 40  Клиент просит не звонить ему на домашний номер...
# 41  ДД! Клиент жалуется что ей звонят по задолженн...
# 42  Добрый день. Клиент Жалуется что про условия к...
# 43  Клиент Қажыбеков Ринат Ержанұлы жалуется на Ба...
# 44  клиент Тленова Рита Есиркеповна жалуется что з...
# 45  контакт неверный, третье лицо не знает ЗК, ном...
# 46            Клиент хочет деактивировать свой номер,
# 47  Клиенту поступают слишком частые звонки в рабо...
# 48  Клиент жалуется на то что при оформлении креди...
# 49  Клиент жалуется на то что он оставлял как 3 ли...
#
#                                             predicted
# 0                               корреспонденцию банка
# 1                               корреспонденцию банка
# 2                               корреспонденцию банка
# 3                                        обслуживание
# 4                                        обслуживание
# 5                                        обслуживание
# 6                                        обслуживание
# 7                                        обслуживание
# 8                                        обслуживание
# 9                                        обслуживание
# 10                                       обслуживание
# 11                                 услугу "страховку"
# 12                                       обслуживание
# 13                                       обслуживание
# 14                          обслуживание в терминалах
# 15                              корреспонденцию банка
# 16                                 услугу "страховку"
# 17                                       обслуживание
# 18                              корреспонденцию банка
# 19                              корреспонденцию банка
# 20                              корреспонденцию банка
# 21                              корреспонденцию банка
# 22                              корреспонденцию банка
# 23                                       обслуживание
# 24                                       обслуживание
# 25                                 услугу "хранитель"
# 26                                       обслуживание
# 27                                       обслуживание
# 28                                       обслуживание
# 29                                 услугу "страховку"
# 30                          обслуживание в терминалах
# 31                                       обслуживание
# 32                              корреспонденцию банка
# 33                                       обслуживание
# 34                                       обслуживание
# 35                                       обслуживание
# 36                                       обслуживание
# 37                                       обслуживание
# 38  не согласие с условиями договора, %%, задолжен...
# 39                              корреспонденцию банка
# 40                              корреспонденцию банка
# 41                              корреспонденцию банка
# 42                                       обслуживание
# 43                                       обслуживание
# 44                              корреспонденцию банка
# 45                              корреспонденцию банка
# 46                              корреспонденцию банка
# 47                              корреспонденцию банка
# 48                                       обслуживание
# 49                              корреспонденцию банка

# %%
frameTest.to_excel('complaints_test.xlsx', sheet_name='complaints_test')
