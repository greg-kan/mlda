# %% [markdown]
# # Анализ таблиц JDWH - Прод vs Тест

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## 1. Загрузка и первичное преобразование данных
# (Это подготовка. Отчеты идут с раздела 2.)

# %% [markdown]
# ### Прод

# %%
prod = pd.read_csv('./data/tables_sizes_prod_12122020.csv')

# %% [markdown]
# Добавим столбец base_name - базовое имя таблиц (без учета партиций).
# Преобразуем last_analyze в дату-время.

# %%
prod['base_name'] = prod['table_name'].apply(lambda x: x.split('_1_prt_')[0])
prod['last_analyze'] = prod.last_analyze.apply(lambda x: None if pd.isna(x) else datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))

# %%
prod.head(3)
# Out:
#   table_schema                table_name    table_size table_size_p  \
# 0    dwh_stage  s01_t_trndtl_1_prt_other  208488562688       194 GB
# 1    dwh_stage             s01_t_operjrn   74459756328        69 GB
# 2      dwh_dds       acc_account_balance  115628942832       108 GB
#
#    indexes_size indexes_size_p    total_size total_size_p  row_count_approx  \
# 0   51620184064          48 GB  260108746752       242 GB        1121557503
# 1  180960886784         169 GB  255420643112       238 GB         922357000
# 2    9779740672        9327 MB  125408683504       117 GB         725052276
#
#          last_analyze  row_count_exact            base_name
# 0 2020-10-08 13:18:32       1122620693         s01_t_trndtl
# 1 2020-10-08 12:41:48        958449833        s01_t_operjrn
# 2 2020-10-05 14:53:31        243607804  acc_account_balance

# %% [markdown]
# Сгруппируем данные по table_schema, base_name (группировка по партициям)

# %%
prod_gr = prod.groupby(['table_schema', 'base_name']).agg(
    table_size = pd.NamedAgg(column = 'table_size', aggfunc = 'sum'),
    indexes_size = pd.NamedAgg(column = 'indexes_size', aggfunc = 'sum'),
    total_size = pd.NamedAgg(column = 'total_size', aggfunc = 'sum'),
    row_count_approx = pd.NamedAgg(column = 'row_count_approx', aggfunc = 'sum'),
    last_analyze_min = pd.NamedAgg(column = 'last_analyze', aggfunc = 'min'),
    last_analyze_max = pd.NamedAgg(column = 'last_analyze', aggfunc = 'max'),
    row_count_exact = pd.NamedAgg(column = 'row_count_exact', aggfunc = 'max'),
)

# %%
prod_gr.reset_index(level=['table_schema', 'base_name'], inplace=True)
prod_gr.head(3)
# Out:
#   table_schema                base_name  table_size  indexes_size  total_size  \
# 0     dwh_bckp      amara_corr_overdues           0        294912      294912
# 1     dwh_bckp       amara_rating_fitch      262144        557056      819200
# 2     dwh_bckp  amara_rating_fitch_bckp      557056             0      557056
#
#    row_count_approx    last_analyze_min    last_analyze_max  row_count_exact
# 0                 0                 NaT                 NaT                0
# 1                 0                 NaT                 NaT              693
# 2                10 2020-08-26 16:06:11 2020-08-26 16:06:11               21

# %%
prod_gr[(prod_gr.table_schema=='dwh_stage') & (prod_gr.base_name=='s01_t_trndtl')]
# Out:
#     table_schema     base_name    table_size  indexes_size    total_size  \
# 522    dwh_stage  s01_t_trndtl  380200091648   93152378880  473352470528
#
#      row_count_approx    last_analyze_min    last_analyze_max  row_count_exact
# 522        1664699176 2020-10-08 13:13:26 2020-10-08 17:46:44       1719055182

# %% [markdown]
# ### Тест

# %%
test = pd.read_csv('./data/tables_sizes_test_12122020.csv')

# %% [markdown]
# Добавим столбец base_name - базовое имя таблиц (без учета партиций). Преобразуем last_analyze в дату-время.

# %%
test['base_name'] = test['table_name'].apply(lambda x: x.split('_1_prt_')[0])
test['last_analyze'] = test.last_analyze.apply(lambda x: None if pd.isna(x) else datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))

# %%
test.head(3)
# Out:
#   table_schema               table_name    table_size table_size_p  \
# 0    dwh_stage  s02_opt_vw_balance_dafb  159287738368       148 GB
# 1    dwh_stage                s09_q_row   79593897984        74 GB
# 2  dwh_polygon        dm_z10_bck_170920   80207675392        75 GB
#
#    indexes_size indexes_size_p    total_size total_size_p  row_count_approx  \
# 0     173473792         165 MB  159461212160       149 GB        1462717913
# 1   14041481216          13 GB   93635379200        87 GB         630123226
# 2             0        0 bytes   80207675392        75 GB                 0
#
#          last_analyze  row_count_exact                base_name
# 0 2020-12-12 17:55:16       1462862288  s02_opt_vw_balance_dafb
# 1 2020-12-12 18:02:07        630183557                s09_q_row
# 2                 NaT        111177183        dm_z10_bck_170920

# %% [markdown]
# Сгруппируем данные по table_schema, base_name (группировка по партициям)

# %%
test_gr = test.groupby(['table_schema', 'base_name']).agg(
    table_size = pd.NamedAgg(column = 'table_size', aggfunc = 'sum'),
    indexes_size = pd.NamedAgg(column = 'indexes_size', aggfunc = 'sum'),
    total_size = pd.NamedAgg(column = 'total_size', aggfunc = 'sum'),
    row_count_approx = pd.NamedAgg(column = 'row_count_approx', aggfunc = 'sum'),
    last_analyze_min = pd.NamedAgg(column = 'last_analyze', aggfunc = 'min'),
    last_analyze_max = pd.NamedAgg(column = 'last_analyze', aggfunc = 'max'),
    row_count_exact = pd.NamedAgg(column = 'row_count_exact', aggfunc = 'max'),
)

# %%
test_gr.reset_index(level=['table_schema', 'base_name'], inplace=True)
test_gr.head(3)
# Out:
#   table_schema                      base_name  table_size  indexes_size  \
# 0     dwh_bckp  amara_daughter_companies_bckp      524288             0
# 1     dwh_bckp             amara_rating_fitch      262144        557056
# 2     dwh_bckp        amara_rating_fitch_bckp      557056             0
#
#    total_size  row_count_approx    last_analyze_min    last_analyze_max  \
# 0      524288                11 2020-11-26 16:09:28 2020-11-26 16:09:28
# 1      819200                 0                 NaT                 NaT
# 2      557056                 0                 NaT                 NaT
#
#    row_count_exact
# 0               13
# 1               42
# 2               42

# %% [markdown]
# Добавим столбцы instance и full_table_name

# %%
prod['instance'] = 'prod'
prod_gr['instance'] = 'prod'
test['instance'] = 'test'
test_gr['instance'] = 'test'

prod['full_table_name'] = prod.table_schema + '.' + prod.table_name
prod_gr['full_table_name'] = prod_gr.table_schema + '.' + prod_gr.base_name
test['full_table_name'] = test.table_schema + '.' + test.table_name
test_gr['full_table_name'] = test_gr.table_schema + '.' + test_gr.base_name

# %%
test_gr.head(1)
# Out:
#   table_schema                      base_name  table_size  indexes_size  \
# 0     dwh_bckp  amara_daughter_companies_bckp      524288             0
#
#    total_size  row_count_approx    last_analyze_min    last_analyze_max  \
# 0      524288                11 2020-11-26 16:09:28 2020-11-26 16:09:28
#
#    row_count_exact instance                         full_table_name
# 0               13     test  dwh_bckp.amara_daughter_companies_bckp

# %%
prod.head(1)
# Out:
#   table_schema                table_name    table_size table_size_p  \
# 0    dwh_stage  s01_t_trndtl_1_prt_other  208488562688       194 GB
#
#    indexes_size indexes_size_p    total_size total_size_p  row_count_approx  \
# 0   51620184064          48 GB  260108746752       242 GB        1121557503
#
#          last_analyze  row_count_exact     base_name instance  \
# 0 2020-10-08 13:18:32       1122620693  s01_t_trndtl     prod
#
#                       full_table_name
# 0  dwh_stage.s01_t_trndtl_1_prt_other

# %% [markdown]
# Добавим поля с размерами в удобочитаемом виде

# %%
def transform_size(sz):
    if sz >= (1024*1024*1024):
        return str(round(sz/(1024*1024*1024))) + ' GB'
    elif sz >= (1024*1024):
        return str(round(sz/(1024*1024))) + ' MB'
    elif sz >= 1024:
        return str(round(sz/1024)) + ' KB'
    else:
        return str(sz) + ' byte'

# %%
test_gr['table_size_p'] = test_gr['table_size'].apply(lambda x: transform_size(x))
test_gr['indexes_size_p'] = test_gr['indexes_size'].apply(lambda x: transform_size(x))
test_gr['total_size_p'] = test_gr['total_size'].apply(lambda x: transform_size(x))

prod_gr['table_size_p'] = prod_gr['table_size'].apply(lambda x: transform_size(x))
prod_gr['indexes_size_p'] = prod_gr['indexes_size'].apply(lambda x: transform_size(x))
prod_gr['total_size_p'] = prod_gr['total_size'].apply(lambda x: transform_size(x))

# %%
test_gr.head(1)
# Out:
#   table_schema                      base_name  table_size  indexes_size  \
# 0     dwh_bckp  amara_daughter_companies_bckp      524288             0
#
#    total_size  row_count_approx    last_analyze_min    last_analyze_max  \
# 0      524288                11 2020-11-26 16:09:28 2020-11-26 16:09:28
#
#    row_count_exact instance                         full_table_name  \
# 0               13     test  dwh_bckp.amara_daughter_companies_bckp
#
#   table_size_p indexes_size_p total_size_p
# 0       512 KB         0 byte       512 KB

# %% [markdown]
# ## 2. Количество таблиц по схемам

# %% [markdown]
# ### Прод

# %% [markdown]
# Все

# %%
prod.table_schema.value_counts()
# Out:
# pg_bitmapindex    2023
# dwh_stage         1865
# dwh_dm             895
# dwh_bckp           763
# dwh_dds            501
# dwh_polygon        136
# dwh_draft           25
# dwh_dq              10
# dwh_private          4
# Name: table_schema, dtype: int64

# %%
#prod.table_schema.value_counts().plot(kind = 'barh', title='Prod: Tables count by schemas')

# %% [markdown]
# С группировкой по партициям

# %%
prod_gr.table_schema.value_counts()
# Out:
# pg_bitmapindex    2023
# dwh_stage          292
# dwh_dds            123
# dwh_polygon        103
# dwh_bckp            29
# dwh_draft           25
# dwh_dm              22
# dwh_dq              10
# dwh_private          4
# Name: table_schema, dtype: int64

# %% [markdown]
# ### ТЕСТ

# %% [markdown]
# Все

# %%
test.table_schema.value_counts()
# Out:
# pg_bitmapindex    4042
# dwh_stage         2264
# dwh_dm            2219
# dwh_bckp           768
# dwh_dds            658
# dwh_dq             377
# dwh_polygon        185
# dwh_rb              37
# dwh_draft           35
# Name: table_schema, dtype: int64

# %% [markdown]
# С группировкой по партициям

# %%
test_gr.table_schema.value_counts()
# Out:
# pg_bitmapindex    4042
# dwh_stage          300
# dwh_polygon        185
# dwh_dds            123
# dwh_rb              37
# dwh_draft           35
# dwh_bckp            34
# dwh_dm              30
# dwh_dq              10
# Name: table_schema, dtype: int64

# %% [markdown]
# ## 3. Top 15 таблиц по размерам и количеству строк

# %% [markdown]
# ### Прод

# %% [markdown]
# По размеру таблицы

# %%
prod_total_size = prod.nlargest(15,'total_size')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
prod_total_size
# Out:
#                                full_table_name table_size_p indexes_size_p  \
# 0           dwh_stage.s01_t_trndtl_1_prt_other       194 GB          48 GB
# 1                      dwh_stage.s01_t_operjrn        69 GB         169 GB
# 2                  dwh_dds.acc_account_balance       108 GB        9327 MB
# 3         dwh_stage.s01_t_trndtl_tmp_1_prt_deb        55 GB          17 GB
# 4        dwh_stage.s01_t_trndtl_tmp_1_prt_cred        52 GB          16 GB
# 5                    dwh_stage.s02_opt_account        68 GB        0 bytes
# 6            dwh_stage.s02_opt_vw_balance_dafb        45 GB          43 MB
# 7   dwh_polygon.s02_opt_vw_balance_dafb_tuleng        41 GB          39 MB
# 8                      dwh_dds.acc_doc_payment        35 GB        1017 MB
# 9            dwh_dm.dm_z10_1_prt_94_2020_10_13        24 GB        1033 MB
# 10           dwh_dm.dm_z10_1_prt_92_2020_09_29        24 GB        1062 MB
# 11           dwh_dm.dm_z10_1_prt_93_2020_10_06        23 GB        1018 MB
# 12           dwh_dm.dm_z10_1_prt_95_2020_10_20        23 GB         993 MB
# 13                      dwh_stage.s01_tt_point        18 GB        5573 MB
# 14           dwh_stage.s02_opt_vw_all_doc_dafb        22 GB         734 MB
#
#    total_size_p  row_count_exact
# 0        242 GB       1122620693
# 1        238 GB        958449833
# 2        117 GB        243607804
# 3         72 GB        562674047
# 4         68 GB        534830816
# 5         68 GB       1133629530
# 6         45 GB        439633296
# 7         41 GB        405916018
# 8         36 GB         15093349
# 9         25 GB          7581848
# 10        25 GB          7597235
# 11        24 GB          7590703
# 12        24 GB          7576185
# 13        23 GB        196129960
# 14        23 GB         33376750

# %% [markdown]
# По размеру таблицы. Сгруппированно по партициям

# %%
prod_gr_total_size = prod_gr.nlargest(15,'total_size')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
prod_gr_total_size
# Out:
#                                 full_table_name table_size_p indexes_size_p  \
# 522                      dwh_stage.s01_t_trndtl       354 GB          87 GB
# 500                     dwh_stage.s01_t_operjrn        69 GB         169 GB
# 164                               dwh_dm.dm_z10       223 GB          10 GB
# 483                         dwh_stage.s01_t_bal       162 GB          54 GB
# 523                  dwh_stage.s01_t_trndtl_tmp       107 GB          32 GB
# 29                  dwh_dds.acc_account_balance       108 GB           9 GB
# 26                 dwh_bckp.s01_led_acc_det_bkp        60 GB          50 GB
# 561                   dwh_stage.s02_opt_account        68 GB         0 byte
# 568           dwh_stage.s02_opt_vw_balance_dafb        45 GB          42 MB
# 302  dwh_polygon.s02_opt_vw_balance_dafb_tuleng        41 GB          39 MB
# 37                      dwh_dds.acc_doc_payment        35 GB        1017 MB
# 554                      dwh_stage.s02_gl_macro        28 GB         0 byte
# 527                      dwh_stage.s01_tt_point        18 GB           5 GB
# 513                     dwh_stage.s01_t_procmem         9 GB          14 GB
# 566           dwh_stage.s02_opt_vw_all_doc_dafb        22 GB         734 MB
#
#     total_size_p  row_count_exact
# 522       441 GB       1719055182
# 500       238 GB        958449833
# 164       233 GB        106203713
# 483       215 GB       1811349736
# 523       140 GB       1097504863
# 29        117 GB        243607804
# 26        110 GB        469350785
# 561        68 GB       1133629530
# 568        45 GB        439633296
# 302        41 GB        405916018
# 37         36 GB         15093349
# 554        28 GB         70207424
# 527        23 GB        196129960
# 513        23 GB        143871033
# 566        23 GB         33376750

# %% [markdown]
# По количеству строк

# %%
prod_row_count = prod.nlargest(15,'row_count_exact')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
prod_row_count
# Out:
#                                  full_table_name table_size_p indexes_size_p  \
# 5846                         dwh_stage.s01_t_bal      0 bytes         288 kB
# 4314           dwh_stage.s01_t_bal_1_prt_no_flzo      0 bytes         288 kB
# 1468                      dwh_stage.s01_t_trndtl      0 bytes        1728 kB
# 5                      dwh_stage.s02_opt_account        68 GB        0 bytes
# 0             dwh_stage.s01_t_trndtl_1_prt_other       194 GB          48 GB
# 6058                  dwh_stage.s01_t_trndtl_tmp      0 bytes         288 kB
# 1                        dwh_stage.s01_t_operjrn        69 GB         169 GB
# 3           dwh_stage.s01_t_trndtl_tmp_1_prt_deb        55 GB          17 GB
# 4          dwh_stage.s01_t_trndtl_tmp_1_prt_cred        52 GB          16 GB
# 1602                dwh_bckp.s01_led_acc_det_bkp      0 bytes        1440 kB
# 6              dwh_stage.s02_opt_vw_balance_dafb        45 GB          43 MB
# 7     dwh_polygon.s02_opt_vw_balance_dafb_tuleng        41 GB          39 MB
# 18                   dwh_stage.s01_t_procmem_old        17 GB        0 bytes
# 2                    dwh_dds.acc_account_balance       108 GB        9327 MB
# 13                        dwh_stage.s01_tt_point        18 GB        5573 MB
#
#      total_size_p  row_count_exact
# 5846       288 kB       1811349736
# 4314       288 kB       1767310882
# 1468      1728 kB       1719055182
# 5           68 GB       1133629530
# 0          242 GB       1122620693
# 6058       288 kB       1097504863
# 1          238 GB        958449833
# 3           72 GB        562674047
# 4           68 GB        534830816
# 1602      1440 kB        469350785
# 6           45 GB        439633296
# 7           41 GB        405916018
# 18          17 GB        267585548
# 2          117 GB        243607804
# 13          23 GB        196129960

# %% [markdown]
# По количеству строк. Сгруппированно по партициям

# %%
prod_gr_row_count = prod_gr.nlargest(15,'row_count_exact')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
prod_gr_row_count
# Out:
#                                 full_table_name table_size_p indexes_size_p  \
# 483                         dwh_stage.s01_t_bal       162 GB          54 GB
# 522                      dwh_stage.s01_t_trndtl       354 GB          87 GB
# 561                   dwh_stage.s02_opt_account        68 GB         0 byte
# 523                  dwh_stage.s01_t_trndtl_tmp       107 GB          32 GB
# 500                     dwh_stage.s01_t_operjrn        69 GB         169 GB
# 26                 dwh_bckp.s01_led_acc_det_bkp        60 GB          50 GB
# 568           dwh_stage.s02_opt_vw_balance_dafb        45 GB          42 MB
# 302  dwh_polygon.s02_opt_vw_balance_dafb_tuleng        41 GB          39 MB
# 516                 dwh_stage.s01_t_procmem_old        17 GB         0 byte
# 29                  dwh_dds.acc_account_balance       108 GB           9 GB
# 527                      dwh_stage.s01_tt_point        18 GB           5 GB
# 513                     dwh_stage.s01_t_procmem         9 GB          14 GB
# 295                   dwh_polygon.s01_t_procmem         9 GB         0 byte
# 515                 dwh_stage.s01_t_procmem_new         9 GB         0 byte
# 503                         dwh_stage.s01_t_ord        17 GB           4 GB
#
#     total_size_p  row_count_exact
# 483       215 GB       1811349736
# 522       441 GB       1719055182
# 561        68 GB       1133629530
# 523       140 GB       1097504863
# 500       238 GB        958449833
# 26        110 GB        469350785
# 568        45 GB        439633296
# 302        41 GB        405916018
# 516        17 GB        267585548
# 29        117 GB        243607804
# 527        23 GB        196129960
# 513        23 GB        143871033
# 295         9 GB        138466533
# 515         9 GB        138130934
# 503        21 GB        128014810

# %% [markdown]
# ### Тест

# %% [markdown]
# По размеру таблицы

# %%
test_total_size = test.nlargest(15,'total_size')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
test_total_size
# Out:
#                                   full_table_name table_size_p indexes_size_p  \
# 0               dwh_stage.s02_opt_vw_balance_dafb       148 GB         165 MB
# 1                             dwh_stage.s09_q_row        74 GB          13 GB
# 2                   dwh_polygon.dm_z10_bck_170920        75 GB        0 bytes
# 3                 dwh_polygon.dm_z10_bck_07122020        73 GB        0 bytes
# 4                       dwh_stage.s02_opt_account        65 GB        0 bytes
# 5                 dwh_polygon.dm_z10_bck_20200805        57 GB        0 bytes
# 6                         dwh_stage.s01_t_operjrn        25 GB          22 GB
# 7        dwh_polygon.acc_account_balance_30102020        32 GB        0 bytes
# 8                             dwh_stage.s09_q_atr        31 GB        0 bytes
# 9               dwh_stage.s02_opt_vw_all_doc_dafb        28 GB         879 MB
# 10         dwh_polygon.acc_account_balance_141020        28 GB        0 bytes
# 11  dwh_polygon.acc_account_balance_bckp_07102020        25 GB        0 bytes
# 12               dwh_bckp.s01_led_acc_det_old_bkp        24 GB        0 bytes
# 13            dwh_polygon.s01_t_trndtl_bck_160720        24 GB        0 bytes
# 14     dwh_polygon.acc_account_balance_bck_170920        23 GB        0 bytes
#
#    total_size_p  row_count_exact
# 0        149 GB       1462862288
# 1         87 GB        630183557
# 2         75 GB        111177183
# 3         73 GB         93822639
# 4         65 GB       1080993022
# 5         57 GB         88544938
# 6         48 GB        353304642
# 7         32 GB        245878627
# 8         31 GB        268490221
# 9         28 GB         41343697
# 10        28 GB        213929262
# 11        25 GB        203272431
# 12        24 GB        280506423
# 13        24 GB        122207433
# 14        23 GB        187247223

# %% [markdown]
# По размеру таблицы. Сгруппированно по партициям

# %%
test_gr_total_size = test_gr.nlargest(15,'total_size')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
test_gr_total_size
# Out:
#                               full_table_name table_size_p indexes_size_p  \
# 174                             dwh_dm.dm_z10       224 GB           5 GB
# 628                       dwh_stage.s01_t_bal       156 GB          55 GB
# 715         dwh_stage.s02_opt_vw_balance_dafb       148 GB         165 MB
# 746                       dwh_stage.s09_q_row        74 GB          13 GB
# 30               dwh_bckp.s01_led_acc_det_bkp        45 GB          32 GB
# 262             dwh_polygon.dm_z10_bck_170920        75 GB         0 byte
# 261           dwh_polygon.dm_z10_bck_07122020        73 GB         0 byte
# 708                 dwh_stage.s02_opt_account        65 GB         0 byte
# 263           dwh_polygon.dm_z10_bck_20200805        57 GB         0 byte
# 646                   dwh_stage.s01_t_operjrn        25 GB          22 GB
# 668                    dwh_stage.s01_t_trndtl        32 GB           8 GB
# 669                dwh_stage.s01_t_trndtl_old        27 GB           7 GB
# 233  dwh_polygon.acc_account_balance_30102020        32 GB         0 byte
# 744                       dwh_stage.s09_q_atr        31 GB         0 byte
# 713         dwh_stage.s02_opt_vw_all_doc_dafb        28 GB         879 MB
#
#     total_size_p  row_count_exact
# 174       229 GB        313835800
# 628       211 GB       1810766559
# 715       149 GB       1462862288
# 746        87 GB        630183557
# 30         78 GB        507036214
# 262        75 GB        111177183
# 261        73 GB         93822639
# 708        65 GB       1080993022
# 263        57 GB         88544938
# 646        48 GB        353304642
# 668        41 GB        162777851
# 669        34 GB        132567276
# 233        32 GB        245878627
# 744        31 GB        268490221
# 713        28 GB         41343697

# %% [markdown]
# По количеству строк

# %%
test_row_count = test.nlargest(15,'row_count_exact')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
test_row_count
# Out:
#                                     full_table_name table_size_p  \
# 8242                            dwh_stage.s01_t_bal      0 bytes
# 7374              dwh_stage.s01_t_bal_1_prt_no_flzo      0 bytes
# 0                 dwh_stage.s02_opt_vw_balance_dafb       148 GB
# 4                         dwh_stage.s02_opt_account        65 GB
# 1                               dwh_stage.s09_q_row        74 GB
# 2462                   dwh_bckp.s01_led_acc_det_bkp      0 bytes
# 6                           dwh_stage.s01_t_operjrn        25 GB
# 1456                                  dwh_dm.dm_z10      1120 kB
# 12                 dwh_bckp.s01_led_acc_det_old_bkp        24 GB
# 8                               dwh_stage.s09_q_atr        31 GB
# 7          dwh_polygon.acc_account_balance_30102020        32 GB
# 10           dwh_polygon.acc_account_balance_141020        28 GB
# 11    dwh_polygon.acc_account_balance_bckp_07102020        25 GB
# 15                           dwh_stage.s01_tt_point        18 GB
# 14       dwh_polygon.acc_account_balance_bck_170920        23 GB
#
#      indexes_size_p total_size_p  row_count_exact
# 8242         288 kB       288 kB       1810766559
# 7374         288 kB       288 kB       1766727714
# 0            165 MB       149 GB       1462862288
# 4           0 bytes        65 GB       1080993022
# 1             13 GB        87 GB        630183557
# 2462        1440 kB      1440 kB        507036214
# 6             22 GB        48 GB        353304642
# 1456        1152 kB      2272 kB        313835800
# 12          0 bytes        24 GB        280506423
# 8           0 bytes        31 GB        268490221
# 7           0 bytes        32 GB        245878627
# 10          0 bytes        28 GB        213929262
# 11          0 bytes        25 GB        203272431
# 15          4286 MB        22 GB        201664324
# 14          0 bytes        23 GB        187247223

# %% [markdown]
# По количеству строк. Сгруппированно по партициям

# %%
test_gr_row_count = test_gr.nlargest(15,'row_count_exact')[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']]
test_gr_row_count
# Out:
#                                        full_table_name table_size_p  \
# 628                                dwh_stage.s01_t_bal       156 GB
# 715                  dwh_stage.s02_opt_vw_balance_dafb       148 GB
# 708                          dwh_stage.s02_opt_account        65 GB
# 746                                dwh_stage.s09_q_row        74 GB
# 30                        dwh_bckp.s01_led_acc_det_bkp        45 GB
# 646                            dwh_stage.s01_t_operjrn        25 GB
# 174                                      dwh_dm.dm_z10       224 GB
# 31                    dwh_bckp.s01_led_acc_det_old_bkp        24 GB
# 744                                dwh_stage.s09_q_atr        31 GB
# 233           dwh_polygon.acc_account_balance_30102020        32 GB
# 232             dwh_polygon.acc_account_balance_141020        28 GB
# 235      dwh_polygon.acc_account_balance_bckp_07102020        25 GB
# 674                             dwh_stage.s01_tt_point        18 GB
# 234         dwh_polygon.acc_account_balance_bck_170920        23 GB
# 237  dwh_polygon.acc_account_balance_s02_bckp_07102020        19 GB
#
#     indexes_size_p total_size_p  row_count_exact
# 628          55 GB       211 GB       1810766559
# 715         165 MB       149 GB       1462862288
# 708         0 byte        65 GB       1080993022
# 746          13 GB        87 GB        630183557
# 30           32 GB        78 GB        507036214
# 646          22 GB        48 GB        353304642
# 174           5 GB       229 GB        313835800
# 31          0 byte        24 GB        280506423
# 744         0 byte        31 GB        268490221
# 233         0 byte        32 GB        245878627
# 232         0 byte        28 GB        213929262
# 235         0 byte        25 GB        203272431
# 674           4 GB        22 GB        201664324
# 234         0 byte        23 GB        187247223
# 237         0 byte        19 GB        162795086

# %% [markdown]
# ## 4.Прод vs Тест

# %% [markdown]
# По размеру с группировкой по партициям

# %%
joined_gr_total_size = prod_gr_total_size.merge(test_gr[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']], on='full_table_name', how='left', suffixes=('_prd', '_tst'))
joined_gr_total_size['row_count_exact_tst'] = joined_gr_total_size['row_count_exact_tst'].astype('Int64')
joined_gr_total_size
# Out:
#                                full_table_name table_size_p_prd  \
# 0                       dwh_stage.s01_t_trndtl           354 GB
# 1                      dwh_stage.s01_t_operjrn            69 GB
# 2                                dwh_dm.dm_z10           223 GB
# 3                          dwh_stage.s01_t_bal           162 GB
# 4                   dwh_stage.s01_t_trndtl_tmp           107 GB
# 5                  dwh_dds.acc_account_balance           108 GB
# 6                 dwh_bckp.s01_led_acc_det_bkp            60 GB
# 7                    dwh_stage.s02_opt_account            68 GB
# 8            dwh_stage.s02_opt_vw_balance_dafb            45 GB
# 9   dwh_polygon.s02_opt_vw_balance_dafb_tuleng            41 GB
# 10                     dwh_dds.acc_doc_payment            35 GB
# 11                      dwh_stage.s02_gl_macro            28 GB
# 12                      dwh_stage.s01_tt_point            18 GB
# 13                     dwh_stage.s01_t_procmem             9 GB
# 14           dwh_stage.s02_opt_vw_all_doc_dafb            22 GB
#
#    indexes_size_p_prd total_size_p_prd  row_count_exact_prd table_size_p_tst  \
# 0               87 GB           441 GB           1719055182            32 GB
# 1              169 GB           238 GB            958449833            25 GB
# 2               10 GB           233 GB            106203713           224 GB
# 3               54 GB           215 GB           1811349736           156 GB
# 4               32 GB           140 GB           1097504863            10 GB
# 5                9 GB           117 GB            243607804             8 GB
# 6               50 GB           110 GB            469350785            45 GB
# 7              0 byte            68 GB           1133629530            65 GB
# 8               42 MB            45 GB            439633296           148 GB
# 9               39 MB            41 GB            405916018              NaN
# 10            1017 MB            36 GB             15093349             6 GB
# 11             0 byte            28 GB             70207424             8 GB
# 12               5 GB            23 GB            196129960            18 GB
# 13              14 GB            23 GB            143871033             9 GB
# 14             734 MB            23 GB             33376750            28 GB
#
#    indexes_size_p_tst total_size_p_tst  row_count_exact_tst
# 0                8 GB            41 GB            162777851
# 1               22 GB            48 GB            353304642
# 2                5 GB           229 GB            313835800
# 3               55 GB           211 GB           1810766559
# 4                3 GB            13 GB            103120628
# 5               86 MB             8 GB             82092911
# 6               32 GB            78 GB            507036214
# 7              0 byte            65 GB           1080993022
# 8              165 MB           149 GB           1462862288
# 9                 NaN              NaN                 <NA>
# 10             541 MB             7 GB             12197807
# 11             0 byte             8 GB             21784256
# 12               4 GB            22 GB            201664324
# 13              11 GB            20 GB            143872608
# 14             879 MB            28 GB             41343697

# %% [markdown]
# По количеству строк с группировкой по партициям

# %%
joined_gr_row_count = prod_gr_row_count.merge(test_gr[['full_table_name', 'table_size_p', 'indexes_size_p', 'total_size_p', 'row_count_exact']], on='full_table_name', how='left', suffixes=('_prd', '_tst'))
joined_gr_row_count['row_count_exact_tst'] = joined_gr_row_count['row_count_exact_tst'].astype('Int64')
joined_gr_row_count
# Out:
#                                full_table_name table_size_p_prd  \
# 0                          dwh_stage.s01_t_bal           162 GB
# 1                       dwh_stage.s01_t_trndtl           354 GB
# 2                    dwh_stage.s02_opt_account            68 GB
# 3                   dwh_stage.s01_t_trndtl_tmp           107 GB
# 4                      dwh_stage.s01_t_operjrn            69 GB
# 5                 dwh_bckp.s01_led_acc_det_bkp            60 GB
# 6            dwh_stage.s02_opt_vw_balance_dafb            45 GB
# 7   dwh_polygon.s02_opt_vw_balance_dafb_tuleng            41 GB
# 8                  dwh_stage.s01_t_procmem_old            17 GB
# 9                  dwh_dds.acc_account_balance           108 GB
# 10                      dwh_stage.s01_tt_point            18 GB
# 11                     dwh_stage.s01_t_procmem             9 GB
# 12                   dwh_polygon.s01_t_procmem             9 GB
# 13                 dwh_stage.s01_t_procmem_new             9 GB
# 14                         dwh_stage.s01_t_ord            17 GB
#
#    indexes_size_p_prd total_size_p_prd  row_count_exact_prd table_size_p_tst  \
# 0               54 GB           215 GB           1811349736           156 GB
# 1               87 GB           441 GB           1719055182            32 GB
# 2              0 byte            68 GB           1133629530            65 GB
# 3               32 GB           140 GB           1097504863            10 GB
# 4              169 GB           238 GB            958449833            25 GB
# 5               50 GB           110 GB            469350785            45 GB
# 6               42 MB            45 GB            439633296           148 GB
# 7               39 MB            41 GB            405916018              NaN
# 8              0 byte            17 GB            267585548              NaN
# 9                9 GB           117 GB            243607804             8 GB
# 10               5 GB            23 GB            196129960            18 GB
# 11              14 GB            23 GB            143871033             9 GB
# 12             0 byte             9 GB            138466533              NaN
# 13             0 byte             9 GB            138130934              NaN
# 14               4 GB            21 GB            128014810            16 GB
#
#    indexes_size_p_tst total_size_p_tst  row_count_exact_tst
# 0               55 GB           211 GB           1810766559
# 1                8 GB            41 GB            162777851
# 2              0 byte            65 GB           1080993022
# 3                3 GB            13 GB            103120628
# 4               22 GB            48 GB            353304642
# 5               32 GB            78 GB            507036214
# 6              165 MB           149 GB           1462862288
# 7                 NaN              NaN                 <NA>
# 8                 NaN              NaN                 <NA>
# 9               86 MB             8 GB             82092911
# 10               4 GB            22 GB            201664324
# 11              11 GB            20 GB            143872608
# 12                NaN              NaN                 <NA>
# 13                NaN              NaN                 <NA>
# 14               4 GB            20 GB            127986984
