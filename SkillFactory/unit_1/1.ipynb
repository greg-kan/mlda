# %%
import pandas as pd

# %%
data = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
                 index = ['Первый', "Второй", "Третий", "Четвёртый"])
display(data)
# Out:
# Первый        Январь
# Второй       Февраль
# Третий          Март
# Четвёртый     Апрель
# dtype: object

# %%
data.loc["Первый"]
# Out:
# 'Январь'

# %%
data.loc[["Первый", "Третий"]]
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
 data["Первый"]
# Out:
# 'Январь'

# %%
data[["Первый", "Третий"]]
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
data.iloc[0]
# Out:
# 'Январь'

# %%
data.iloc[[0, 2]]
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
data = pd.Series(list(range(10, 1001)))

# %%
data
# Out:
# 0        10
# 1        11
# 2        12
# 3        13
# 4        14
# 5        15
# 6        16
# 7        17
# 8        18
# 9        19
# 10       20
# 11       21
# 12       22
# 13       23
# 14       24
# 15       25
# 16       26
# 17       27
# 18       28
# 19       29
# 20       30
# 21       31
# 22       32
# 23       33
# 24       34
# 25       35
# 26       36
# 27       37
# 28       38
# 29       39
#        ...
# 961     971
# 962     972
# 963     973
# 964     974
# 965     975
# 966     976
# 967     977
# 968     978
# 969     979
# 970     980
# 971     981
# 972     982
# 973     983
# 974     984
# 975     985
# 976     986
# 977     987
# 978     988
# 979     989
# 980     990
# 981     991
# 982     992
# 983     993
# 984     994
# 985     995
# 986     996
# 987     997
# 988     998
# 989     999
# 990    1000
# Length: 991, dtype: int64

# %%
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# -70

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
display(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df = pd.DataFrame([ [1,2,3], [2,3,4] ],
                  columns = ['foo', 'bar', 'baz'], 
                  index = ['foobar', 'foobaz'])
display(df)
# Out:
#         foo  bar  baz
# foobar    1    2    3
# foobaz    2    3    4

# %%
data = pd.read_csv('data_sf.xls')

# %%
data.head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
# Unnamed: 0         12897 non-null int64
# Name               12897 non-null object
# Age                12897 non-null int64
# Nationality        12897 non-null object
# Club               12897 non-null object
# Value              12897 non-null int64
# Wage               12897 non-null int64
# Position           12897 non-null object
# Crossing           12897 non-null int64
# Finishing          12897 non-null int64
# HeadingAccuracy    12897 non-null int64
# ShortPassing       12897 non-null int64
# Volleys            12897 non-null int64
# Dribbling          12897 non-null int64
# Curve              12897 non-null int64
# FKAccuracy         12897 non-null int64
# LongPassing        12897 non-null int64
# BallControl        12897 non-null int64
# Acceleration       12897 non-null int64
# SprintSpeed        12897 non-null int64
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
data.describe(include = ['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
df = pd.DataFrame([[i, i + 1.2, i + 2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
df
# Out:
#    foo   bar  baz foobar
# 0    0   1.2    2     hi
# 1    1   2.2    3     hi
# 2    2   3.2    4     hi
# 3    3   4.2    5     hi
# 4    4   5.2    6     hi
# 5    5   6.2    7     hi
# 6    6   7.2    8     hi
# 7    7   8.2    9     hi
# 8    8   9.2   10     hi
# 9    9  10.2   11     hi

# %%
df.mean()
# Out:
# foo    4.5
# bar    5.7
# baz    6.5
# dtype: float64

# %%
df['bar'].mean()
# Out:
# 5.7

# %%
df.baz.max()
# Out:
# 11

# %%
data.describe(include = ['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
data.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
data.Age.mean()
# Out:
# 24.795378770256647

# %%
data.Composure.count()
# Out:
# 12897

# %%
data.ShortPassing.std()
# Out:
# 14.740435689517149

# %%
data.Wage.sum()
# Out:
# 96954000

# %%
data.Value.min()
# Out:
# 0

# %%
data[data.Age > 43]
# Out:
#        Unnamed: 0           Name  Age        Nationality                Club  \
# 1628         1695       O. Pérez   45             Mexico             Pachuca
# 12422       12651      T. Warner   44  Trinidad & Tobago  Accrington Stanley
# 12873       13102  K. Pilkington   44            England    Cambridge United
#
#          Value  Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 1628   1300000  8000       GK        19         14  ...         23         62
# 12422        0  1000       GK        19         13  ...         17         46
# 12873        0  1000       GK        11         12  ...         22         56
#
#        Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 1628        23              12             11        70          64
# 12422       19              15             14        48          56
# 12873       15              15             13        45          48
#
#        GKKicking  GKPositioning  GKReflexes
# ...

# %%
data[   (data.Age < data.Age.mean()) | (data.Club == 'FC Barcelona')  ]
# Out:
#        Unnamed: 0                  Name  Age          Nationality  \
# 0               0              L. Messi   31            Argentina
# 7               7             L. Suárez   31              Uruguay
# 15             15             P. Dybala   24            Argentina
# 16             16               H. Kane   24              England
# 18             18         M. ter Stegen   26              Germany
# 20             20       Sergio Busquets   29                Spain
# 25             25             K. Mbappé   19               France
# 32             32              Coutinho   26               Brazil
# 42             42             S. Umtiti   24               France
# 49             49            Jordi Alba   29                Spain
# 53             53            I. Rakitić   30              Croatia
# 54             54                 Piqué   31                Spain
# 55             55               L. Sané   22              Germany
# ...

# %%
data[data.Age > data.Age.mean()]
# Out:
#        Unnamed: 0               Name  Age        Nationality  \
# 0               0           L. Messi   31          Argentina
# 1               1  Cristiano Ronaldo   33           Portugal
# 2               2          Neymar Jr   26             Brazil
# 3               3             De Gea   27              Spain
# 4               4       K. De Bruyne   27            Belgium
# 5               5          E. Hazard   27            Belgium
# 6               6          L. Modrić   32            Croatia
# 7               7          L. Suárez   31            Uruguay
# 8               8       Sergio Ramos   32              Spain
# 9               9           J. Oblak   25           Slovenia
# 10             10     R. Lewandowski   29             Poland
# 11             11           T. Kroos   28            Germany
# 12             12           D. Godín   32            Uruguay
# 13             13        David Silva   32              Spain
# ...

# %%
data[ (data.Age < data.Age.mean()) & (data.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
data[ data.Wage > data.Wage.mean() ].SprintSpeed.mean()
# Out:
# 67.56638061585058

# %%
data[ data.Wage < data.Wage.mean() ].SprintSpeed.mean()
# Out:
# 62.41425430560645

# %%
data[ data.Wage == data.Wage.max() ].Position
# Out:
# 0    RF
# Name: Position, dtype: object

# %%
data[ data.Nationality == 'Brazil' ].Penalties.sum()
# Out:
# 22789

# %%
data[ data.HeadingAccuracy > 50 ].Age.mean()
# Out:
# 25.58771113179944

# %%
data[ (data.Composure > 0.9 * data.Composure.max() ) & (data.Reactions > 0.9 * data.Reactions.max())].Age.min()
# Out:
# 24

# %%
data[ data.Age == data.Age.max() ].Reactions.mean() - data[ data.Age == data.Age.min() ].Reactions.mean()
# Out:
# 22.642857142857146

# %%
data[ data.Value > data.Value.mean() ].Nationality .describe(include = ['object'])
# Out:
# count      1747
# unique       98
# top       Spain
# freq        211
# Name: Nationality, dtype: object

# %%
data[ (data.Position == 'GK') & (data.GKReflexes == data.GKReflexes.max()) ].Wage.mean() / data[ (data.Position == 'GK') & (data.GKHandling == data.GKHandling.max()) ].Wage.mean()
# Out:
# 2.765957446808511

# %%
data[ data.Aggression == data.Aggression.max() ].ShotPower.mean() / data[ data.Aggression == data.Aggression.min() ].ShotPower.mean()
# Out:
# 2.076923076923077
