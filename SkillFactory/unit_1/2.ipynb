# %%
import pandas as pd

# %%
df = pd.read_csv('data_sf.xls')

# %%
df.head(250)
# Out:
#      Unnamed: 0               Name  Age     Nationality  \
# 0             0           L. Messi   31       Argentina
# 1             1  Cristiano Ronaldo   33        Portugal
# 2             2          Neymar Jr   26          Brazil
# 3             3             De Gea   27           Spain
# 4             4       K. De Bruyne   27         Belgium
# 5             5          E. Hazard   27         Belgium
# 6             6          L. Modrić   32         Croatia
# 7             7          L. Suárez   31         Uruguay
# 8             8       Sergio Ramos   32           Spain
# 9             9           J. Oblak   25        Slovenia
# 10           10     R. Lewandowski   29          Poland
# 11           11           T. Kroos   28         Germany
# 12           12           D. Godín   32         Uruguay
# 13           13        David Silva   32           Spain
# 14           14           N. Kanté   27          France
# 15           15          P. Dybala   24       Argentina
# ...

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Uruguay      3
# Germany      3
# Argentina    3
# Belgium      3
# France       2
# Portugal     1
# Italy        1
# Poland       1
# England      1
# Croatia      1
# Brazil       1
# Slovenia     1
# Name: Nationality, dtype: int64

# %%
s = small_df.Nationality.value_counts()
display(s)
# Out:
# Spain        4
# Belgium      3
# Argentina    3
# Germany      3
# Uruguay      3
# France       2
# Slovenia     1
# Croatia      1
# England      1
# Italy        1
# Poland       1
# Portugal     1
# Brazil       1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Belgium', 'Argentina', 'Germany', 'Uruguay', 'France',
#        'Slovenia', 'Croatia', 'England', 'Italy', 'Poland', 'Portugal',
#        'Brazil'],
#       dtype='object')

# %%
s.index[0]
# Out:
# 'Spain'

# %%
len(s.index)
# Out:
# 13

# %%
len(s)
# Out:
# 13

# %%
s['Germany']
# Out:
# 3

# %%
s.Germany
# Out:
# 3

# %%
s.loc[s > 1]
# Out:
# Spain        4
# Belgium      3
# Argentina    3
# Germany      3
# Uruguay      3
# France       2
# Name: Nationality, dtype: int64

# %%
s[s > 1]
# Out:
# Spain        4
# Belgium      3
# Argentina    3
# Germany      3
# Uruguay      3
# France       2
# Name: Nationality, dtype: int64

# %%
s = small_df['Club'].value_counts()
display(s)
# Out:
# Real Madrid            4
# FC Barcelona           4
# Juventus               3
# Manchester City        3
# Atlético Madrid        3
# Paris Saint-Germain    2
# Chelsea                2
# FC Bayern München      2
# Manchester United      1
# Tottenham Hotspur      1
# Name: Club, dtype: int64

# %%
len(s)
# Out:
# 10

# %%
s = df['Club'].value_counts()
display(s)
# Out:
# V-Varen Nagasaki             30
# Shonan Bellmare              30
# FC Emmen                     29
# Vissel Kobe                  29
# De Graafschap                29
# Padova                       29
# FC Energie Cottbus           28
# Al Batin                     28
# Livingston FC                28
# Doncaster Rovers             28
# Gillingham                   28
# Sangju Sangmu FC             28
# Bury                         28
# Morecambe                    28
# Coventry City                28
# Accrington Stanley           28
# San Martín de San Juan       28
# Yeovil Town                  28
# Mansfield Town               28
# Júbilo Iwata                 28
# Colchester United            28
# Curicó Unido                 28
# Blackpool                    28
# Lincoln City                 28
# Cambridge United             28
# Cosenza                      28
# Sagan Tosu                   28
# Northampton Town             28
# Crewe Alexandra              28
# ...

# %%
len(s)
# Out:
# 650

# %%
s = small_df['Nationality'].value_counts(normalize=True)
display(s)
# Out:
# Spain        0.16
# Belgium      0.12
# Argentina    0.12
# Germany      0.12
# Uruguay      0.12
# France       0.08
# Slovenia     0.04
# Croatia      0.04
# England      0.04
# Italy        0.04
# Poland       0.04
# Portugal     0.04
# Brazil       0.04
# Name: Nationality, dtype: float64

# %%
s = df['Position'].value_counts(normalize=True)
display(s)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# RF     0.000465
# LAM    0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
s = small_df['Age'].value_counts()
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 29    2
# 24    2
# 33    2
# 30    1
# 28    1
# 25    1
# Name: Age, dtype: int64

# %%
s = small_df['Wage'].value_counts()
display(s)
# Out:
# 205000    3
# 355000    2
# 240000    2
# 300000    1
# 130000    1
# 225000    1
# 455000    1
# 340000    1
# 315000    1
# 565000    1
# 405000    1
# 215000    1
# 380000    1
# 285000    1
# 145000    1
# 290000    1
# 125000    1
# 200000    1
# 420000    1
# 94000     1
# 260000    1
# Name: Wage, dtype: int64

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
s.index
# Out:
# IntervalIndex([(211750.0, 329500.0], (93528.999, 211750.0], (329500.0, 447250.0], (447250.0, 565000.0]],
#               closed='right',
#               dtype='interval[float64]')

# %%
s.index[3]
# Out:
# Interval(447250.0, 565000.0, closed='right')

# %%
s.index[3].left
# Out:
# 447250.0

# %%
s.index[3].right
# Out:
# 565000.0

# %%
small_df['Wage'] > s.index[3].left
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: Wage, dtype: bool

# %%
small_df[small_df['Wage'] > s.index[3].left]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
s = df['FKAccuracy'].value_counts(bins=5)
display(s)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
s = small_df['Nationality'].value_counts()
print(s.index)
print(len(s.index))
# Out:
# Index(['Spain', 'Belgium', 'Argentina', 'Germany', 'Uruguay', 'France',
#        'Slovenia', 'Croatia', 'England', 'Italy', 'Poland', 'Portugal',
#        'Brazil'],
#       dtype='object')
# 13

# %%
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
len(small_df['Nationality'].unique())
# Out:
# 13

# %%
small_df['Nationality'].nunique()
# Out:
# 13

# %%
result = len(df['Position'].value_counts())
result
# Out:
# 27

# %%
s = small_df['Nationality'].value_counts()
s_df = s.reset_index()
display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1     Belgium            3
# 2   Argentina            3
# 3     Germany            3
# 4     Uruguay            3
# 5      France            2
# 6    Slovenia            1
# 7     Croatia            1
# 8     England            1
# 9       Italy            1
# 10     Poland            1
# 11   Portugal            1
# 12     Brazil            1

# %%
s_df.columns = ['Nationality','Players Count']
display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1      Belgium              3
# 2    Argentina              3
# 3      Germany              3
# 4      Uruguay              3
# 5       France              2
# 6     Slovenia              1
# 7      Croatia              1
# 8      England              1
# 9        Italy              1
# 10      Poland              1
# 11    Portugal              1
# 12      Brazil              1

# %%
small_df[small_df['Wage'] > s.index[3].left]

# %%
df[df['Nationality'] == 'Spain']['Wage'].value_counts(bins=4, normalize=True)
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
df[df['Club'] == 'Manchester United']['Nationality'].nunique()
# Out:
# 13

# %%
df[(df['Nationality'] == 'Brazil') & (df['Club'] == 'Juventus')]
# Out:
#     Unnamed: 0           Name  Age Nationality      Club     Value    Wage  \
# 64          64    Alex Sandro   27      Brazil  Juventus  36500000  160000
# 65          65  Douglas Costa   27      Brazil  Juventus  46500000  175000
#
#    Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 64       LB        84         55  ...         60         82       81
# 65       LM        84         67  ...         77         84       45
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 64              84             84         7           7          9
# 65              38             34        13          15          9
#
#     GKPositioning  GKReflexes
# 64             12           5
# 65             12           5
#
# [2 rows x 42 columns]

# %%
df[df['Age'] > 35]['Club'].value_counts()
# Out:
# Club Atlético Huracán            4
# Hokkaido Consadole Sapporo       4
# Estudiantes de La Plata          3
# Hammarby IF                      3
# San Martín de San Juan           3
# Gimnasia y Esgrima La Plata      3
# Nagoya Grampus                   3
# Club Atlético Talleres           3
# Club Atlético Colón              3
# Club Atlético Tigre              3
# Benevento                        3
# Morecambe                        3
# Rochdale                         2
# Atlético Tucumán                 2
# Once Caldas                      2
# Al Hilal                         2
# Livorno                          2
# Lobos BUAP                       2
# San Lorenzo de Almagro           2
# Cork City                        2
# Guizhou Hengfeng FC              2
# Unión La Calera                  2
# Kashima Antlers                  2
# Empoli                           2
# Elche CF                         2
# Júbilo Iwata                     2
# River Plate                      2
# ...

# %%
df[df['Nationality'] == 'Argentina']['Age'].value_counts(bins = 4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
df[df['Nationality'] == 'Spain']['Age'].value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
df.groupby(['Club'])

# %%
df.groupby(['Club']).groups
# Out:
# {' SSV Jahn Regensburg': Int64Index([ 1642,  2284,  2374,  2401,  2575,  2583,  2850,  2868,  3418,
#               3908,  3989,  4154,  5151,  5177,  5525,  5885,  6070,  6679,
#               7173,  7477,  8905,  9061, 10825, 12482],
#             dtype='int64'),
#  '1. FC Heidenheim 1846': Int64Index([ 1060,  1805,  1978,  2050,  2066,  2926,  3584,  3605,  4312,
#               4457,  4783,  6818,  7160,  7166,  7460,  9475, 10052, 10565,
#              11217, 12236],
#             dtype='int64'),
#  '1. FC Kaiserslautern': Int64Index([ 2931,  3590,  4270,  4413,  4475,  4483,  4709,  4779,  5079,
#               5325,  5403,  5855,  5917,  7295,  8784,  9496,  9964, 10019,
#              10122, 10671, 11500, 11970, 12222],
#             dtype='int64'),
#  '1. FC Köln': Int64Index([166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], dtype='int64'),
#  '1. FC Magdeburg': Int64Index([ 1967,  2069,  2152,  2569,  2886,  3030,  3300,  3332,  4436,
# ...

# %%
grouped_df = df.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                           Unnamed: 0  Age      Value     Wage  Crossing  \
# Club
#  SSV Jahn Regensburg          129124  609   15195000    90000      1104
# 1. FC Heidenheim 1846         117834  473   18290000    76000       961
# 1. FC Kaiserslautern          167351  544   11195000    33000      1106
# 1. FC Köln                     54865  225   46810000    92000       444
# 1. FC Magdeburg               116731  515   57525000    84000       948
# 1. FC Nürnberg                 75281  291   28540000    93000       646
# 1. FC Union Berlin             61586  271    9485000    94000       572
# 1. FSV Mainz 05                59103  238   41755000   125000       574
# AC Ajaccio                    118215  507   24000000    42000       958
# AC Horsens                    210346  625    8650000    55000      1141
# AD Alcorcón                    89198  506   36875000    70000      1000
# ADO Den Haag                  114251  450   14680000    67000       972
# ...

# %%
grouped_df.loc['Ajax']
# Out:
# Unnamed: 0             26041
# Age                      275
# Value              152250000
# Wage                  158000
# Crossing                 844
# Finishing                723
# HeadingAccuracy          848
# ShortPassing             940
# Volleys                  696
# Dribbling                932
# Curve                    779
# FKAccuracy               680
# LongPassing              878
# BallControl              951
# Acceleration             944
# SprintSpeed              969
# Agility                  969
# Reactions                924
# Balance                  918
# ShotPower                876
# Jumping                  915
# Stamina                  974
# Strength                 896
# LongShots                720
# Aggression               847
# Interceptions            801
# Positioning              813
# Vision                   881
# Penalties                710
# Composure                929
# Marking                  750
# StandingTackle           814
# ...

# %%
grouped_df.iloc[1]
# Out:
# Unnamed: 0           117834
# Age                     473
# Value              18290000
# Wage                  76000
# Crossing                961
# Finishing               860
# HeadingAccuracy         955
# ShortPassing           1136
# Volleys                 846
# Dribbling              1040
# Curve                   904
# FKAccuracy              823
# LongPassing             940
# BallControl            1099
# Acceleration           1285
# SprintSpeed            1309
# Agility                1273
# Reactions              1188
# Balance                1203
# ShotPower              1103
# Jumping                1237
# Stamina                1208
# Strength               1280
# LongShots               872
# Aggression             1023
# Interceptions           919
# Positioning             896
# Vision                  958
# Penalties               923
# Composure              1093
# Marking                 888
# StandingTackle          952
# SlidingTackle           890
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
df.groupby(['Club']).sum().loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum()
display(grouped_df)
# Out:
# Club
#  SSV Jahn Regensburg          90000
# 1. FC Heidenheim 1846         76000
# 1. FC Kaiserslautern          33000
# 1. FC Köln                    92000
# 1. FC Magdeburg               84000
# 1. FC Nürnberg                93000
# 1. FC Union Berlin            94000
# 1. FSV Mainz 05              125000
# AC Ajaccio                    42000
# AC Horsens                    55000
# AD Alcorcón                   70000
# ADO Den Haag                  67000
# AEK Athens                    11000
# AFC Wimbledon                 51000
# AIK                           46000
# AJ Auxerre                    34000
# AS Béziers                    31000
# AS Monaco                    770000
# AS Nancy Lorraine             53000
# AS Saint-Étienne             213000
# AZ Alkmaar                    60000
# Aalborg BK                    59000
# Aarhus GF                     72000
# Aberdeen                      49000
# Accrington Stanley            67000
# Adelaide United               33000
# ...

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
#display(grouped_df)
grouped_df.head(5)
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
grouped_df
#grouped_df.head(20)
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# CDM     4921000
# RCB     4711000
# LCB     3989000
# RW      3276000
# RCM     3241000
# LCM     3145000
# LW      2945000
# LS      1866000
# RDM     1557000
# RS      1537000
# LDM     1516000
# RF       714000
# LF       601000
# RWB      420000
# LAM      366000
# LWB      347000
# CF       248000
# RAM       59000
# Name: Wage, dtype: int64

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                               Wage        Age  ShotPower
# Nationality
# Afghanistan            1250.000000  22.500000  53.750000
# Albania                5931.034483  23.689655  54.551724
# Algeria               15810.810811  27.027027  56.567568
# Andorra                1000.000000  28.000000  58.000000
# Angola                 7100.000000  24.700000  63.700000
# Antigua & Barbuda      1333.333333  23.000000  50.333333
# Argentina             10264.808362  25.890244  54.033101
# Armenia                8500.000000  26.750000  66.375000
# Australia              2223.300971  24.174757  47.325243
# Austria                5441.666667  24.341667  50.650000
# Azerbaijan             2200.000000  26.000000  69.800000
# Barbados               3666.666667  27.666667  52.333333
# Belarus                4500.000000  27.500000  43.000000
# Belgium               20024.390244  24.030488  56.390244
# Belize                 1000.000000  25.000000  66.000000
# ...

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
df[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False).head(10)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06

# %%
df.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#                       Club  Name
# Nationality
# Afghanistan              4     4
# Albania                 26    29
# Algeria                 33    37
# Andorra                  1     1
# Angola                   9    10
# Antigua & Barbuda        3     3
# Argentina              133   554
# Armenia                  8     8
# Australia               51   205
# Austria                 47   240
# Azerbaijan               5     5
# Barbados                 3     3
# Belarus                  2     2
# Belgium                 68   164
# Belize                   1     1
# Benin                    8     8
# Bermuda                  1     1
# Bolivia                  5     5
# Bosnia Herzegovina      35    37
# Botswana                 1     1
# Brazil                 173   408
# Bulgaria                 8     8
# Burkina Faso            12    12
# Burundi                  2     2
# Cameroon                49    55
# Canada                  29    52
# Cape Verde               7     8
# ...

# %%
df.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg        24
# 1. FC Heidenheim 1846       20
# 1. FC Kaiserslautern        23
# 1. FC Köln                  10
# 1. FC Magdeburg             21
# 1. FC Nürnberg              13
# 1. FC Union Berlin          11
# 1. FSV Mainz 05             11
# AC Ajaccio                  19
# AC Horsens                  25
# AD Alcorcón                 19
# ADO Den Haag                19
# AEK Athens                  11
# AFC Wimbledon               26
# AIK                         19
# AJ Auxerre                  17
# AS Béziers                  25
# AS Monaco                   18
# AS Nancy Lorraine           25
# AS Saint-Étienne            15
# AZ Alkmaar                  10
# Aalborg BK                  22
# Aarhus GF                   25
# Aberdeen                    18
# Accrington Stanley          28
# Adelaide United             24
# Ajax                        13
# Akhisar Belediyespor        14
# Al Ahli                     22
# Al Batin                    28
# ...

# %%
df.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg        57.5
# 1. FC Heidenheim 1846       59.5
# 1. FC Kaiserslautern        54.0
# 1. FC Köln                  60.5
# 1. FC Magdeburg             53.0
# 1. FC Nürnberg              57.0
# 1. FC Union Berlin          61.0
# 1. FSV Mainz 05             71.0
# AC Ajaccio                  61.0
# AC Horsens                  58.0
# AD Alcorcón                 62.0
# ADO Den Haag                62.0
# AEK Athens                  63.0
# AFC Wimbledon               55.5
# AIK                         60.0
# AJ Auxerre                  58.0
# AS Béziers                  58.0
# AS Monaco                   61.5
# AS Nancy Lorraine           57.0
# AS Saint-Étienne            60.0
# AZ Alkmaar                  63.5
# Aalborg BK                  56.0
# Aarhus GF                   60.0
# Aberdeen                    57.5
# Accrington Stanley          55.0
# Adelaide United             57.0
# Ajax                        71.0
# Akhisar Belediyespor        65.5
# ...

# %%
df.groupby(['Club'])['Strength'].max()
# Out:
# Club
#  SSV Jahn Regensburg        92
# 1. FC Heidenheim 1846       86
# 1. FC Kaiserslautern        85
# 1. FC Köln                  76
# 1. FC Magdeburg             86
# 1. FC Nürnberg              84
# 1. FC Union Berlin          87
# 1. FSV Mainz 05             85
# AC Ajaccio                  82
# AC Horsens                  87
# AD Alcorcón                 88
# ADO Den Haag                90
# AEK Athens                  87
# AFC Wimbledon               91
# AIK                         92
# AJ Auxerre                  90
# AS Béziers                  84
# AS Monaco                   90
# AS Nancy Lorraine           83
# AS Saint-Étienne            78
# AZ Alkmaar                  77
# Aalborg BK                  80
# Aarhus GF                   82
# Aberdeen                    84
# Accrington Stanley          86
# Adelaide United             89
# Ajax                        87
# Akhisar Belediyespor        81
# Al Ahli                     83
# Al Batin                    90
# ...

# %%
df.groupby(['Club'])['Balance'].min()
# Out:
# Club
#  SSV Jahn Regensburg        29
# 1. FC Heidenheim 1846       22
# 1. FC Kaiserslautern        29
# 1. FC Köln                  31
# 1. FC Magdeburg             19
# 1. FC Nürnberg              44
# 1. FC Union Berlin          24
# 1. FSV Mainz 05             39
# AC Ajaccio                  54
# AC Horsens                  35
# AD Alcorcón                 38
# ADO Den Haag                28
# AEK Athens                  29
# AFC Wimbledon               25
# AIK                         26
# AJ Auxerre                  30
# AS Béziers                  35
# AS Monaco                   35
# AS Nancy Lorraine           34
# AS Saint-Étienne            22
# AZ Alkmaar                  38
# Aalborg BK                  33
# Aarhus GF                   27
# Aberdeen                    44
# Accrington Stanley          38
# Adelaide United             25
# Ajax                        59
# Akhisar Belediyespor        35
# Al Ahli                     38
# Al Batin                    34
# ...

# %%
df.groupby(['Club'])['Wage'].mean()
# Out:
# Club
#  SSV Jahn Regensburg         3750.000000
# 1. FC Heidenheim 1846        3800.000000
# 1. FC Kaiserslautern         1434.782609
# 1. FC Köln                   9200.000000
# 1. FC Magdeburg              4000.000000
# 1. FC Nürnberg               7153.846154
# 1. FC Union Berlin           8545.454545
# 1. FSV Mainz 05             11363.636364
# AC Ajaccio                   2210.526316
# AC Horsens                   2200.000000
# AD Alcorcón                  3684.210526
# ADO Den Haag                 3526.315789
# AEK Athens                   1000.000000
# AFC Wimbledon                1961.538462
# AIK                          2421.052632
# AJ Auxerre                   2000.000000
# AS Béziers                   1240.000000
# AS Monaco                   42777.777778
# AS Nancy Lorraine            2120.000000
# AS Saint-Étienne            14200.000000
# AZ Alkmaar                   6000.000000
# Aalborg BK                   2681.818182
# Aarhus GF                    2880.000000
# ...

# %%
df_grouped = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])
#df[df['Nationality'] == 'Argentina']
len(df_grouped[df_grouped['mean'] == df_grouped['median']])
# Out:
# 52

# %%
df_grouped[df_grouped['mean'] == df_grouped['median']].sort_values(['mean'],ascending=False).head(10)
# Out:
#                       mean  median
# Club
# Cruzeiro           13000.0   13000
# Göztepe SK          7000.0    7000
# Brøndby IF          6000.0    6000
# Sunderland          4000.0    4000
# CD Feirense         4000.0    4000
# 1. FC Magdeburg     4000.0    4000
# Northampton Town    2500.0    2500
# Stade Brestois 29   2000.0    2000
# Jeonnam Dragons     2000.0    2000
# Pohang Steelers     2000.0    2000

# %%
df.groupby(['Club'])['Wage'].sum()['Chelsea']
# Out:
# 2035000

# %%
df[df['Age'] == 20].groupby(['Nationality'])['Wage'].max().loc['Argentina']
# Out:
# 54000

# %%
df[df['Age'] == 30].groupby(['Nationality'])['Wage'].max().loc['Argentina']
# Out:
# 300000

# %%
df[df['Age'] == 30].groupby(['Nationality'])['Wage'].min().loc['Argentina']
# Out:
# 1000

# %%
df[df['Nationality'] == 'Argentina'].groupby(['Club'])['Strength', 'Balance'].max().loc['FC Barcelona']
# Out:
# Strength    59
# Balance     95
# Name: FC Barcelona, dtype: int64

# %%
df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])]
# Out:
#       Unnamed: 0               Name  Age         Nationality  \
# 0              0           L. Messi   31           Argentina
# 1              1  Cristiano Ronaldo   33            Portugal
# 3              3             De Gea   27               Spain
# 6              6          L. Modrić   32             Croatia
# 7              7          L. Suárez   31             Uruguay
# 8              8       Sergio Ramos   32               Spain
# 11            11           T. Kroos   28             Germany
# 15            15          P. Dybala   24           Argentina
# 18            18      M. ter Stegen   26             Germany
# 19            19        T. Courtois   26             Belgium
# 20            20    Sergio Busquets   29               Spain
# 24            24       G. Chiellini   33               Italy
# 27            27           Casemiro   26              Brazil
# 30            30               Isco   26               Spain
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])]\
.pivot_table(values=['Wage'], index=['Nationality'], columns=['Club'], aggfunc='sum', margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %%
pivot.loc['Belgium']
# Out:
#       Club
# Wage  FC Barcelona         110000.0
#       Juventus                  NaN
#       Manchester United    230000.0
#       Real Madrid          240000.0
#       All                  580000.0
# Name: Belgium, dtype: float64

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])]\
.pivot_table(values=['Wage'], index=['Nationality'], columns=['Club'], aggfunc='sum', margins=True, fill_value=0)
pivot
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])] \
.pivot_table(values=['Name'], index=['Nationality'], columns=['Club'], aggfunc='count', fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])] \
.pivot_table(values=['Name'], index=['Nationality'], columns=['Club'], aggfunc='count', fill_value=0)
display(pivot)

# %%
pivot = df.loc[df['Position'] != 'CM'] \
.pivot_table(values=['Name'], index=['Club'], columns=['Position'], aggfunc='count', margins=False, fill_value=0)
pivot
# Out:
#                          Name                                  ...             \
# Position                  CAM CB CDM CF GK LAM LB LCB LCM LDM  ... RB RCB RCM
# Club                                                           ...
#  SSV Jahn Regensburg        0  5   1  0  3   0  2   0   0   1  ...  2   1   0
# 1. FC Heidenheim 1846       1  3   0  0  2   0  2   1   0   0  ...  2   1   0
# 1. FC Kaiserslautern        0  3   3  0  3   0  2   1   0   0  ...  2   0   0
# 1. FC Köln                  0  1   1  0  3   0  0   0   0   0  ...  1   0   0
# 1. FC Magdeburg             0  4   0  1  3   0  1   1   1   0  ...  0   1   1
# 1. FC Nürnberg              1  1   2  0  1   0  1   0   0   0  ...  1   0   0
# 1. FC Union Berlin          1  2   2  0  1   0  2   1   0   0  ...  1   0   0
# 1. FSV Mainz 05             0  2   0  0  1   0  1   0   1   0  ...  1   0   0
# AC Ajaccio                  3  1   0  0  1   0  3   1   0   1  ...  1   1   0
# ...

# %%
pivot = df.pivot_table(values=['Name'], index=['Position'], columns=['Club'], aggfunc='count', margins=False, fill_value=0)
pivot
# Out:
#                          Name                                             \
# Club      SSV Jahn Regensburg 1. FC Heidenheim 1846 1. FC Kaiserslautern
# Position
# CAM                         0                     1                    0
# CB                          5                     3                    3
# CDM                         1                     0                    3
# CF                          0                     0                    0
# CM                          2                     1                    0
# GK                          3                     2                    3
# LAM                         0                     0                    0
# LB                          2                     2                    2
# LCB                         0                     1                    1
# LCM                         0                     0                    0
# LDM                         1                     0                    0
# ...

# %%
pivot = df.pivot_table(columns='Position', index = 'Club',values = 'Name', aggfunc='count', fill_value=0)
pivot
# Out:
# Position                  CAM  CB  CDM  CF  CM  GK  LAM  LB  LCB  LCM  ...  \
# Club                                                                   ...
#  SSV Jahn Regensburg        0   5    1   0   2   3    0   2    0    0  ...
# 1. FC Heidenheim 1846       1   3    0   0   1   2    0   2    1    0  ...
# 1. FC Kaiserslautern        0   3    3   0   0   3    0   2    1    0  ...
# 1. FC Köln                  0   1    1   0   2   3    0   0    0    0  ...
# 1. FC Magdeburg             0   4    0   1   0   3    0   1    1    1  ...
# 1. FC Nürnberg              1   1    2   0   1   1    0   1    0    0  ...
# 1. FC Union Berlin          1   2    2   0   1   1    0   2    1    0  ...
# 1. FSV Mainz 05             0   2    0   0   1   1    0   1    0    1  ...
# AC Ajaccio                  3   1    0   0   1   1    0   3    1    0  ...
# AC Horsens                  0   3    1   0   2   3    0   3    1    1  ...
# ...

# %%
posCM = pivot['CM'].value_counts()
posCM
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %%
pivot = df.pivot_table(columns='Nationality', index = 'Club', values = 'Wage', aggfunc='sum', fill_value=0)
pivot1 = pivot['Russia']['AS Monaco']
pivot1
#pivot['Russia'].value_counts()
#pvt = pivot['AS Monaco']
#pvt
# Out:
# 61000

# %%
pivot = df.pivot_table(columns='Position', index = 'Club', values = 'SprintSpeed', aggfunc='mean', fill_value=0)
pivot
# Out:
# Position                        CAM         CB        CDM    CF         CM  \
# Club
#  SSV Jahn Regensburg       0.000000  46.600000  82.000000   0.0  61.000000
# 1. FC Heidenheim 1846     68.000000  61.333333   0.000000   0.0  68.000000
# 1. FC Kaiserslautern       0.000000  59.000000  65.666667   0.0   0.000000
# 1. FC Köln                 0.000000  60.000000  32.000000   0.0  68.500000
# 1. FC Magdeburg            0.000000  60.000000   0.000000  64.0   0.000000
# 1. FC Nürnberg            66.000000  55.000000  59.000000   0.0  53.000000
# 1. FC Union Berlin        61.000000  59.000000  66.500000   0.0  72.000000
# 1. FSV Mainz 05            0.000000  71.500000   0.000000   0.0  69.000000
# AC Ajaccio                71.333333  46.000000   0.000000   0.0  77.000000
# AC Horsens                 0.000000  53.333333  56.000000   0.0  62.500000
# AD Alcorcón                0.000000  56.000000  69.000000   0.0  63.000000
# ...

# %%
pivot.max().sort_values(ascending = False).head(3)
# Out:
# Position
# RS    94.0
# RM    94.0
# LM    94.0
# dtype: float64

# %%
pivot['ST'].sort_values(ascending = False).head(3)
# Out:
# Club
# Vitória      91.0
# Sydney FC    88.0
# CD Lugo      87.0
# Name: ST, dtype: float64
