# %% [markdown]
# # Transfer learning в решении задачи классификации цветов
# Датасет классификации цветов (http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) состоит из 102 видов цветов встречаемых в Великобритании. Для каждого класса есть от 40 до 258 примеров, чего мало для обучения с нуля:
# <img src="http://bennycheung.github.io/images/deep-transfer-learning-on-small-dataset/flower_train_samples_700.jpg" style="width:50%">

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
import pickle
import scipy.io
import tarfile
import csv

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.models as M
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
import tensorflow.keras.callbacks as C
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import optimizers

# %%
from sklearn.model_selection import train_test_split

# %%
import PIL
from PIL import ImageOps, ImageFilter
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 
# %matplotlib inline

# %%
print(os.listdir("/data1/datasets/flowers"))
print('Python       :', sys.version.split('\n')[0])
print('Numpy        :', np.__version__)
print('Tensorflow   :', tf.__version__)
print('Keras        :', keras.__version__)
# Out:
# ['imagelabels.mat', '102flowers.tgz']
# Python       : 3.9.12 (main, Jun  1 2022, 11:38:51)
# Numpy        : 1.22.3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       2 print('Python       :', sys.version.split('\n')[0])
#       3 print('Numpy        :', np.__version__)
# ----> 4 print('Tensorflow   :', tf.__version__)
#       5 print('Keras        :', keras.__version__)
#
# NameError: name 'tf' is not defined

# %%
# Проверяем что у нас работает GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !pip freeze > requirements.txt
# Out:
# /bin/bash: /home/greg/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %% [markdown]
# # Setup

# %%
EPOCHS               = 25
BATCH_SIZE           = 64 # 128
LR                   = 1e-3
VAL_SPLIT            = 0.2

CLASS_NUM            = 102
IMG_SIZE             = 128
IMG_CHANNELS         = 3
input_shape          = (IMG_SIZE, IMG_SIZE, IMG_CHANNELS)

DATA_PATH = '/data1/datasets/flowers/'
PATH = DATA_PATH + "work/"

# %%
os.makedirs(PATH,exist_ok=False)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 os.makedirs(PATH,exist_ok=False)
#
# File ~/anaconda3/envs/tf/lib/python3.9/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: '/data1/datasets/flowers/work/'

# %%
# Setting seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)  
PYTHONHASHSEED = 0

# %% [markdown]
# # Data

# %%
# прочитаем все названия файлов прям из архива и таргеты к ним
def get_all_filenames(tar_fn):
    with tarfile.open(tar_fn) as f:
        return [m.name for m in f.getmembers() if m.isfile()]

df = pd.DataFrame()
df['Id'] = sorted(get_all_filenames(DATA_PATH+"102flowers.tgz"))
df['Category'] = scipy.io.loadmat(DATA_PATH+'imagelabels.mat')['labels'][0] - 1  # классы (0, 1, 2, ...)
df['Category'] = df['Category'].astype(str)

# %%
df.head(5)
# Out:
#                     Id Category
# 0  jpg/image_00001.jpg       76
# 1  jpg/image_00002.jpg       76
# 2  jpg/image_00003.jpg       76
# 3  jpg/image_00004.jpg       76
# 4  jpg/image_00005.jpg       76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8189 entries, 0 to 8188
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        8189 non-null   object
#  1   Category  8189 non-null   object
# dtypes: object(2)
# memory usage: 128.1+ KB

# %%
df['Category'].value_counts()
# Out:
# 50    258
# 76    251
# 45    196
# 72    194
# 88    184
#      ...
# 6      40
# 44     40
# 33     40
# 0      40
# 26     40
# Name: Category, Length: 102, dtype: int64

# %%
df['Category'].nunique()
# Out:
# 102

# %%
print('Распаковываем картинки')
# Will unzip the files so that you can see them..
opened_tar = tarfile.open(DATA_PATH + "102flowers.tgz")
opened_tar.extractall(PATH)
print(os.listdir(PATH+'jpg')[:5])
# Out:
# Распаковываем картинки
# ['image_01453.jpg', 'image_02490.jpg', 'image_05444.jpg', 'image_00272.jpg', 'image_01171.jpg']

# %%
print('Пример картинок (random sample)')
plt.figure(figsize=(12,8))

random_image = df.sample(n=9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values

for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(PATH+path)
    plt.subplot(3,3, index+1)
    plt.imshow(im)
    plt.title('Class: '+str(random_image_cat[index]))
    plt.axis('off')
plt.show()
# Out:
# Пример картинок (random sample)

# %%
# убедимся что метки классов подгрузились верно
print('Пример картинок (random sample)')
plt.figure(figsize=(12,8))

random_image = df[df['Category']=='1'].sample(n=9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values

for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(PATH+path)
    plt.subplot(3,3, index+1)
    plt.imshow(im)
    plt.title('Class: '+str(random_image_cat[index]))
    plt.axis('off')
plt.show()
# Out:
# Пример картинок (random sample)

# %%
# как видим изображения имеют разный размер
image = PIL.Image.open(PATH+path)
imgplot = plt.imshow(image)
plt.show()
image.size
# Out:
# (667, 500)

# %% [markdown]
#  ## Stratify Split

# %%
# трейн / тест
train_files, test_files, train_labels, test_labels = \
    train_test_split(df['Id'], df['Category'], test_size=0.2, random_state=RANDOM_SEED, stratify=df['Category'])

train_files = pd.DataFrame(train_files)
test_files = pd.DataFrame(test_files)
train_files['Category'] = train_labels
test_files['Category'] = test_labels

train_files.shape, test_files.shape
# Out:
# ((6551, 2), (1638, 2))

# %%
train_files.head(5)
# Out:
#                        Id Category
# 2361  jpg/image_02362.jpg       42
# 512   jpg/image_00513.jpg       87
# 5969  jpg/image_05970.jpg       68
# 6251  jpg/image_06252.jpg       60
# 516   jpg/image_00517.jpg       87

# %%
train_files['Category'].value_counts()
# Out:
# 50    206
# 76    201
# 45    157
# 72    155
# 88    147
#      ...
# 0      32
# 6      32
# 33     32
# 2      32
# 26     32
# Name: Category, Length: 102, dtype: int64

# %%
test_files['Category'].value_counts()
# Out:
# 50    52
# 76    50
# 72    39
# 45    39
# 88    37
#       ..
# 78     8
# 0      8
# 20     8
# 24     8
# 66     8
# Name: Category, Length: 102, dtype: int64

# %% [markdown]
# ### Data augmentation

# %%
# Аугментация данных очень важна когда у нас не большой датасет (как в нашем случае)

train_datagen = ImageDataGenerator(rescale=1. / 255, horizontal_flip=False)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
# # for v2
# train_datagen = ImageDataGenerator(rescale=1. / 255, 
#                                     rotation_range = 50,
#                                     shear_range=0.2,
#                                     zoom_range=[0.75,1.25],
#                                     brightness_range=[0.5, 1.5],
#                                     width_shift_range=0.1,
#                                     height_shift_range=0.1,
#                                     horizontal_flip=True)
# test_datagen = ImageDataGenerator(rescale=1. / 255)

# %% [markdown]
# ### datagen

# %%
# "Заворачиваем" наши данные в generator

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_files,
    directory=PATH,
    x_col="Id",
    y_col="Category",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, 
    seed=RANDOM_SEED,)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_files,
    directory=PATH,
    x_col="Id",
    y_col="Category",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False, 
    seed=RANDOM_SEED,)
# Out:
# Found 6551 validated image filenames belonging to 102 classes.
# Found 1638 validated image filenames belonging to 102 classes.

# %%
from skimage import io

# %%
def imshow(image_RGB):
    io.imshow(image_RGB)
    io.show()

# %%
x,y = test_generator.next()
print('Пример картинок из test_generator')
plt.figure(figsize=(12,8))

for i in range(0,9):
    image = x[i]
    plt.subplot(3,3, i+1)
    plt.imshow(image)
    #plt.title('Class: '+str(y[i]))
    #plt.axis('off')
plt.show()
# Out:
# Пример картинок из test_generator

# %% [markdown]
# # Model

# %%
input_shape
# Out:
# (128, 128, 3)

# %%
# !nvidia-smi
# Out:
# /bin/bash: /home/greg/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Tue Jul 26 15:26:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.48.07    Driver Version: 515.48.07    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0  On |                  N/A |
# | 30%   43C    P3    84W / 350W |  12049MiB / 12288MiB |     40%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1421      G   /usr/lib/xorg/Xorg                 53MiB |
# |    0   N/A  N/A      2791      G   /usr/lib/xorg/Xorg                218MiB |
# |    0   N/A  N/A      2928      G   /usr/bin/gnome-shell               39MiB |
# |    0   N/A  N/A      4997      G   ...uncher/minecraft-launcher       13MiB |
# |    0   N/A  N/A      5143      G   ...linux/jre-legacy/bin/java      199MiB |
# |    0   N/A  N/A      5328      G   ...356098832556794092,131072      109MiB |
# |    0   N/A  N/A     14451      C   ...conda3/envs/tf/bin/python    10987MiB |
# |    0   N/A  N/A     16610      C   ...conda3/envs/tf/bin/python      409MiB |
# +-----------------------------------------------------------------------------+

# %%
model = M.Sequential()

# model layer 1
model.add(L.Convolution2D(128, (3, 3), input_shape=input_shape, activation='relu', padding='same',))
model.add(L.BatchNormalization())
model.add(L.Convolution2D(128, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())

# Pooling layer 1
model.add(L.MaxPooling2D(pool_size=(2,2)))
model.add(L.Dropout(0.2))

# model and pooling layer 2
model.add(L.Convolution2D(256, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())
model.add(L.Convolution2D(256, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())

model.add(L.MaxPooling2D(pool_size=(2,2)))
model.add(L.Dropout(0.3))

# model and pooling layer 3.
model.add(L.Convolution2D(512, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())
model.add(L.Convolution2D(512, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())

model.add(L.MaxPooling2D(pool_size=(2,2)))
model.add(L.Dropout(0.3))


# Flattening
model.add(L.Flatten())

# Full connection
model.add(L.Dense(512, activation='relu'))
model.add(L.Dropout(0.25))
model.add(L.Dense(CLASS_NUM, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 128)     3584
#
#  batch_normalization (BatchN  (None, 128, 128, 128)    512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 128)     147584
#
#  batch_normalization_1 (Batc  (None, 128, 128, 128)    512
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 128)      0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 64, 64, 256)      1024
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 256)       590080
#
#  batch_normalization_3 (Batc  (None, 64, 64, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 512)       1180160
#
#  batch_normalization_4 (Batc  (None, 32, 32, 512)      2048
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 512)       2359808
#
#  batch_normalization_5 (Batc  (None, 32, 32, 512)      2048
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 512)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 512)       0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 512)               67109376
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 102)               52326
#
# =================================================================
# Total params: 71,745,254
# Trainable params: 71,741,670
# Non-trainable params: 3,584
# _________________________________________________________________

# %%
# сколько слоев
print(len(model.layers))
# Out:
# 22

# %%
len(model.trainable_variables)
# Out:
# 28

# %% [markdown]
# ## Fit

# %%
MODEL_PATH = DATA_PATH + "model/"
os.makedirs(MODEL_PATH, exist_ok=False)

# %%
checkpoint = ModelCheckpoint(MODEL_PATH + 'best_model.hdf5' , monitor = ['val_accuracy'] , verbose = 1  , mode = 'max')
earlystop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
callbacks_list = [checkpoint, earlystop]

# %%
#LR=0.0001
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adamax(learning_rate=LR), metrics=["accuracy"])

# %%
scores = model.evaluate(test_generator, steps=1, verbose=1) # model.evaluate_generator
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 2022-07-26 14:52:56.862144: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-07-26 14:52:56.862526: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 1/1 [==============================] - 2s 2s/step - loss: 4.6257 - accuracy: 0.0156
# Accuracy: 1.56%

# %%
# Обучаем
history = model.fit( # model.fit_generator
        train_generator,
        steps_per_epoch = train_generator.samples//train_generator.batch_size,
        validation_data = test_generator, 
        validation_steps = test_generator.samples//test_generator.batch_size,
        epochs = EPOCHS,
        callbacks = callbacks_list
)
# Out:
# Epoch 1/25
# 102/102 [==============================] - ETA: 0s - loss: 10.4249 - accuracy: 0.0348
# Epoch 1: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 24s 211ms/step - loss: 10.4249 - accuracy: 0.0348 - val_loss: 8.4993 - val_accuracy: 0.0294
# Epoch 2/25
# 102/102 [==============================] - ETA: 0s - loss: 4.6701 - accuracy: 0.0603
# Epoch 2: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 23s 222ms/step - loss: 4.6701 - accuracy: 0.0603 - val_loss: 6.7253 - val_accuracy: 0.0206
# Epoch 3/25
# 102/102 [==============================] - ETA: 0s - loss: 4.5044 - accuracy: 0.0752
# Epoch 3: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 23s 222ms/step - loss: 4.5044 - accuracy: 0.0752 - val_loss: 7.1780 - val_accuracy: 0.0288
# Epoch 4/25
# 102/102 [==============================] - ETA: 0s - loss: 4.3835 - accuracy: 0.0822
# Epoch 4: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 23s 224ms/step - loss:
saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 23s 223ms/step - loss: 3.4312 - accuracy: 0.2363 - val_loss: 4.1882 - val_accuracy: 0.1956
# Epoch 18/25
# 102/102 [==============================] - ETA: 0s - loss: 3.2752 - accuracy: 0.2540
# Epoch 18: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 24s 230ms/step - loss: 3.2752 - accuracy: 0.2540 - val_loss: 4.1626 - val_accuracy: 0.1925
# Epoch 19/25
# 102/102 [==============================] - ETA: 0s - loss: 3.1859 - accuracy: 0.2667
# Epoch 19: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 247ms/step - loss: 3.1859 - accuracy: 0.2667 - val_loss: 4.1709 - val_accuracy: 0.2212
# Epoch 20/25
# 102/102 [==============================] - ETA: 0s - loss: 3.0847 - accuracy: 0.2921
# Epoch 20: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 246ms/step - loss: 3.0847 - accuracy: 0.2921 - val_loss: 4.1767 - val_accuracy: 0.2087
# Epoch 21/25
# 102/102 [==============================] - ETA: 0s - loss: 2.9864 - accuracy: 0.3120
# Epoch 21: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 27s 261ms/step - loss: 2.9864 - accuracy: 0.3120 - val_loss: 4.3119 - val_accuracy: 0.2044
# Epoch 22/25
# 102/102 [==============================] - ETA: 0s - loss: 2.8948 - accuracy: 0.3220
# Epoch 22: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 27s 260ms/step - loss: 2.8948 - accuracy: 0.3220 - val_loss: 4.1524 - val_accuracy: 0.2331
# Epoch 23/25
# 102/102 [==============================] - ETA: 0s - loss: 2.7411 - accuracy: 0.3524
# Epoch 23: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 246ms/step - loss: 2.7411 - accuracy: 0.3524 - val_loss: 4.0888 - val_accuracy: 0.2506
# Epoch 24/25
# 102/102 [==============================] - ETA: 0s - loss: 2.6902 - accuracy: 0.3604
# Epoch 24: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 243ms/step - loss: 2.6902 - accuracy: 0.3604 - val_loss: 4.2690 - val_accuracy: 0.2625
# Epoch 25/25
# 102/102 [==============================] - ETA: 0s - loss: 2.5859 - accuracy: 0.3911
# Epoch 25: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s 250ms/step - loss: 2.5859 - accuracy: 0.3911 - val_loss: 4.1431 - val_accuracy: 0.2700

# %%
model.save(MODEL_PATH + 'model_last.hdf5')
model.load_weights(MODEL_PATH + 'model_last.hdf5')

# %%
scores = model.evaluate(test_generator, steps=1, verbose=1) # model.evaluate_generator
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 1/1 [==============================] - 0s 221ms/step - loss: 5.5003 - accuracy: 0.1406
# Accuracy: 14.06%

# %%
def plot_history(history):
    plt.figure(figsize=(10,5))
    plt.style.use('dark_background')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'b', label='Training acc')
    plt.plot(epochs, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    
    plt.show()

    #plt.figure()
    plt.figure(figsize=(10,5))
    plt.style.use('dark_background')
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'g', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %%
plot_history(history)

# %%
K.clear_session()

# %%
LR=0.0001
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adamax(learning_rate=LR), metrics=["accuracy"])

# %%
history = model.fit( # model.fit_generator
        train_generator,
        steps_per_epoch = train_generator.samples//train_generator.batch_size,
        validation_data = test_generator, 
        validation_steps = test_generator.samples//test_generator.batch_size,
        epochs = EPOCHS,
        callbacks = callbacks_list
)
# Out:
# Epoch 1/25
# 102/102 [==============================] - ETA: 0s - loss: 2.2198 - accuracy: 0.4430
# Epoch 1: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s 253ms/step - loss: 2.2198 - accuracy: 0.4430 - val_loss: 3.8416 - val_accuracy: 0.3150
# Epoch 2/25
# 102/102 [==============================] - ETA: 0s - loss: 2.1238 - accuracy: 0.4637
# Epoch 2: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s
saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s 253ms/step - loss: 1.5981 - accuracy: 0.5708 - val_loss: 3.6815 - val_accuracy: 0.3425
# Epoch 16/25
# 102/102 [==============================] - ETA: 0s - loss: 1.5552 - accuracy: 0.5761
# Epoch 16: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s 250ms/step - loss: 1.5552 - accuracy: 0.5761 - val_loss: 3.7086 - val_accuracy: 0.3369
# Epoch 17/25
# 102/102 [==============================] - ETA: 0s - loss: 1.5345 - accuracy: 0.5859
# Epoch 17: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s 251ms/step - loss: 1.5345 - accuracy: 0.5859 - val_loss: 3.7142 - val_accuracy: 0.3444
# Epoch 18/25
# 102/102 [==============================] - ETA: 0s - loss: 1.5040 - accuracy: 0.5964
# Epoch 18: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 249ms/step - loss: 1.5040 - accuracy: 0.5964 - val_loss: 3.7390 - val_accuracy: 0.3425
# Epoch 19/25
# 102/102 [==============================] - ETA: 0s - loss: 1.4632 - accuracy: 0.6046
# Epoch 19: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s 249ms/step - loss: 1.4632 - accuracy: 0.6046 - val_loss: 3.6647 - val_accuracy: 0.3487
# Epoch 20/25
# 102/102 [==============================] - ETA: 0s - loss: 1.4403 - accuracy: 0.6040
# Epoch 20: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 243ms/step - loss: 1.4403 - accuracy: 0.6040 - val_loss: 3.6760 - val_accuracy: 0.3512
# Epoch 21/25
# 102/102 [==============================] - ETA: 0s - loss: 1.4126 - accuracy: 0.6092
# Epoch 21: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 247ms/step - loss: 1.4126 - accuracy: 0.6092 - val_loss: 3.7205 - val_accuracy: 0.3506
# Epoch 22/25
# 102/102 [==============================] - ETA: 0s - loss: 1.3817 - accuracy: 0.6180
# Epoch 22: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 26s 254ms/step - loss: 1.3817 - accuracy: 0.6180 - val_loss: 3.7104 - val_accuracy: 0.3425
# Epoch 23/25
# 102/102 [==============================] - ETA: 0s - loss: 1.3705 - accuracy: 0.6226
# Epoch 23: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 247ms/step - loss: 1.3705 - accuracy: 0.6226 - val_loss: 3.6224 - val_accuracy: 0.3512
# Epoch 24/25
# 102/102 [==============================] - ETA: 0s - loss: 1.3358 - accuracy: 0.6310
# Epoch 24: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 248ms/step - loss: 1.3358 - accuracy: 0.6310 - val_loss: 3.6996 - val_accuracy: 0.3456
# Epoch 25/25
# 102/102 [==============================] - ETA: 0s - loss: 1.2936 - accuracy: 0.6389
# Epoch 25: saving model to /data1/datasets/flowers/model/best_model.hdf5
# 102/102 [==============================] - 25s 247ms/step - loss: 1.2936 - accuracy: 0.6389 - val_loss: 3.6371 - val_accuracy: 0.3575

# %%
model.save(MODEL_PATH + 'model_last.hdf5')
model.load_weights(MODEL_PATH + 'model_last.hdf5')

# %%
scores = model.evaluate(test_generator, steps=1, verbose=1) # evaluate_generator
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 1/1 [==============================] - 0s 225ms/step - loss: 5.1067 - accuracy: 0.2969
# Accuracy: 29.69%

# %%
plot_history(history)

# %%
# Clean PATHs
import shutil
shutil.rmtree(PATH)
shutil.rmtree(MODEL_PATH)
