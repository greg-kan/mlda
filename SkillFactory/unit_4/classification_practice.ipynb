# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 100) # выведем больше строк
pd.set_option('display.max_columns', 100) # выведем больше колонок

# %%
df = pd.read_csv('train_mobile.csv', sep=';')

# %%
df.sample(5)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 233            1442     0          1.0         1   0       0          27
# 1617            634     1          0.8         0   5       0          41
# 1742            657     1          1.9         1   2       0          21
# 56              823     1          2.7         1  13       0          60
# 1656           1150     1          0.5         1   4       1          27
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 233     0.1        192        3  19        231       687  2227     6     5
# 1617    0.2        192        1  12       1362      1853  3242    18    11
# 1742    0.1        110        8   8        705      1905   783     6     1
# 56      0.5        148        8  19        822      1449   905    14    11
# 1656    1.0        134        1  17        234      1947  1610    11     0
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.rcParams['figure.figsize'] = (15,10)
sns.heatmap(df.corr())

# %%
(abs(df.corr())['price_range'].sort_values()[:-1])[15:]
# Out:
# touch_screen     0.040001
# px_height        0.097951
# px_width         0.116703
# battery_power    0.149402
# ram              0.822354
# Name: price_range, dtype: float64

# %%
df1 = df[['touch_screen', 'px_height', 'px_width', 'battery_power', 'ram', 'price_range']]

# %%
df1.head()
# Out:
#    touch_screen  px_height  px_width  battery_power   ram  price_range
# 0             0         20       756            842  2549            0
# 1             1        905      1988           1021  2631            1
# 2             1       1263      1716            563  2603            1
# 3             0       1216      1786            615  2769            1
# 4             1       1208      1212           1821  1411            0

# %%
X = df1[['touch_screen', 'px_height', 'px_width', 'battery_power', 'ram']]
y = df1['price_range']

# %%
X.sample(5)
# Out:
#       touch_screen  px_height  px_width  battery_power   ram
# 850              1        987      1081            840  3486
# 235              1        148      1606           1523   707
# 771              0        486      1930            550   302
# 59               1        127       683           1063  2910
# 1032             1        387      1595           1753  1445

# %%
y.sample(5)
# Out:
# 1440    1
# 4       0
# 1173    1
# 314     1
# 1013    1
# Name: price_range, dtype: int64

# %%
from sklearn.model_selection import train_test_split # функция, чтобы разбить данные на трейн и тест
from sklearn.linear_model import LogisticRegression # наша модель для классификации
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state=31)
#model = LogisticRegression(max_iter=10000)
model = LogisticRegression(random_state=31)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=31, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_predicted = model.predict(X_val)

# %%
y_predicted[:10]
# Out:
# array([1, 0, 1, 1, 0, 0, 1, 1, 1, 0], dtype=int64)

# %%
y_predicted.sum()
# Out:
# 213

# %%
len(y_predicted)
# Out:
# 400

# %%
len(y_val)
# Out:
# 400

# %%
y_val.sum()
# Out:
# 212

# %%
TP_FP = y_predicted.sum()
TP_FP
# Out:
# 213

# %%
y_val.values[:10]
# Out:
# array([1, 0, 1, 1, 0, 0, 1, 1, 1, 0], dtype=int64)

# %%
count = 0
for i in range(len(y_val)):
    if ((y_predicted[i] == 1) & (y_val.values[i] == 1)):
        count+=1

# %%
count
# Out:
# 210

# %%
precis = count/TP_FP
precis
# Out:
# 0.9859154929577465

# %%
print(accuracy_score(y_val,y_predicted))
print(precision_score(y_val,y_predicted))
print(recall_score(y_val,y_predicted))
print(f1_score(y_val,y_predicted))
# Out:
# 0.9875
# 0.9859154929577465
# 0.9905660377358491
# 0.9882352941176472
