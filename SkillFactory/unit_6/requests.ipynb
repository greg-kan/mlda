# %%
import requests

# %% [markdown]
# part 1 - requests

# %%
response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
# {
#     "Date": "2020-12-16T11:30:00+03:00",
#     "PreviousDate": "2020-12-15T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2020\/12\/15\/daily_json.js",
#     "Timestamp": "2020-12-15T23:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 55.2309,
#             "Previous": 55.1548
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 43.2285,
#             "Previous": 42.9236
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 97.8585,
#             "Previous": 97.6495
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 14.0632,
#             "Previous": 13.9707
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 29.0275,
#             "Previous": 28.8524
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 45.5955,
#             "Previous": 45.3105
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 14.347,
#             "Previous": 14.3951
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 25.1948,
#             "Previous": 25.0338
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 94.7461,
#             "Previous": 94.0778
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 11.9829,
#             "Previous": 11.9076
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 73.4453,
#             "Previous": 72.9272
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 89.1846,
#             "Previous": 88.5847
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 99.7221,
#             "Previous": 99.1195
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 17.4832,
#             "Previous": 17.4209
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 57.55,
#             "Previous": 57.2023
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 86.559,
#             "Previous": 85.9716
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 11.2219,
#             "Previous": 11.1557
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 42.7754,
#             "Previous": 42.3872
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 84.071,
#             "Previous": 83.7243
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 20.0742,
#             "Previous": 19.9779
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 18.3164,
#             "Previous": 18.1981
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 105.6599,
#             "Previous": 104.6112
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 55.0276,
#             "Previous": 54.6722
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 64.8524,
#             "Previous": 64.3807
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 93.5812,
#             "Previous": 91.9115
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 21.0144,
#             "Previous": 20.8662
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 70.1945,
#             "Previous": 70.3863
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 26.443,
#             "Previous": 26.1622
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 33.838,
#             "Previous": 33.6582
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 87.2884,
#             "Previous": 86.7128
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 82.8206,
#             "Previous": 82.1808
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 48.9606,
#             "Previous": 48.599
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 67.1334,
#             "Previous": 66.7969
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 70.5493,
#             "Previous": 70.1864
#         }
#     }
# }

# %%
currencies = response.json()  
print(currencies)
# Out:
# {'Date': '2020-12-16T11:30:00+03:00', 'PreviousDate': '2020-12-15T11:30:00+03:00', 'PreviousURL': '//www.cbr-xml-daily.ru/archive/2020/12/15/daily_json.js', 'Timestamp': '2020-12-15T23:00:00+03:00', 'Valute': {'AUD': {'ID': 'R01010', 'NumCode': '036', 'CharCode': 'AUD', 'Nominal': 1, 'Name': 'Австралийский доллар', 'Value': 55.2309, 'Previous': 55.1548}, 'AZN': {'ID': 'R01020A', 'NumCode': '944', 'CharCode': 'AZN', 'Nominal': 1, 'Name': 'Азербайджанский манат', 'Value': 43.2285, 'Previous': 42.9236}, 'GBP': {'ID': 'R01035', 'NumCode': '826', 'CharCode': 'GBP', 'Nominal': 1, 'Name': 'Фунт стерлингов Соединенного королевства', 'Value': 97.8585, 'Previous': 97.6495}, 'AMD': {'ID': 'R01060', 'NumCode': '051', 'CharCode': 'AMD', 'Nominal': 100, 'Name': 'Армянских драмов', 'Value': 14.0632, 'Previous': 13.9707}, 'BYN': {'ID': 'R01090B', 'NumCode': '933', 'CharCode': 'BYN', 'Nominal': 1, 'Name': 'Белорусский рубль', 'Value': 29.0275, 'Previous': 28.8524}, 'BGN': {'ID': 'R01100', 'NumCode': '975', 'CharCode': 'BGN', 'Nominal': 1, 'Name': 'Болгарский лев', 'Value': 45.5955, 'Previous': 45.3105}, 'BRL': {'ID': 'R01115', 'NumCode': '986', 'CharCode': 'BRL', 'Nominal': 1, 'Name': 'Бразильский реал', 'Value': 14.347, 'Previous': 14.3951}, 'HUF': {'ID': 'R01135', 'NumCode': '348', 'CharCode': 'HUF', 'Nominal': 100, 'Name': 'Венгерских форинтов', 'Value': 25.1948, 'Previous': 25.0338}, 'HKD': {'ID': 'R01200', 'NumCode': '344', 'CharCode': 'HKD', 'Nominal': 10, 'Name': 'Гонконгских долларов', 'Value': 94.7461, 'Previous': 94.0778}, 'DKK': {'ID': 'R01215', 'NumCode': '208', 'CharCode': 'DKK', 'Nominal': 1, 'Name': 'Датская крона', 'Value': 11.9829, 'Previous': 11.9076}, 'USD': {'ID': 'R01235', 'NumCode': '840', 'CharCode': 'USD', 'Nominal': 1, 'Name': 'Доллар США', 'Value': 73.4453, 'Previous': 72.9272}, 'EUR': {'ID': 'R01239', 'NumCode': '978', 'CharCode': 'EUR', 'Nominal': 1, 'Name': 'Евро', 'Value': 89.1846, 'Previous': 88.5847}, 'INR': {'ID': 'R01270', 'NumCode': '356', 'CharCode': 'INR', 'Nominal': 100, 'Name': 'Индийских рупий', 'Value': 99.7221, 'Previous': 99.1195}, 'KZT': {'ID': 'R01335', 'NumCode': '398', 'CharCode': 'KZT', 'Nominal': 100, 'Name': 'Казахстанских тенге', 'Value': 17.4832, 'Previous': 17.4209}, 'CAD': {'ID': 'R01350', 'NumCode': '124', 'CharCode': 'CAD', 'Nominal': 1, 'Name': 'Канадский доллар', 'Value': 57.55, 'Previous': 57.2023}, 'KGS': {'ID': 'R01370', 'NumCode': '417', 'CharCode': 'KGS', 'Nominal': 100, 'Name': 'Киргизских сомов', 'Value': 86.559, 'Previous': 85.9716}, 'CNY': {'ID': 'R01375', 'NumCode': '156', 'CharCode': 'CNY', 'Nominal': 1, 'Name': 'Китайский юань', 'Value': 11.2219, 'Previous': 11.1557}, 'MDL': {'ID': 'R01500', 'NumCode': '498', 'CharCode': 'MDL', 'Nominal': 10, 'Name': 'Молдавских леев', 'Value': 42.7754, 'Previous': 42.3872}, 'NOK': {'ID': 'R01535', 'NumCode': '578', 'CharCode': 'NOK', 'Nominal': 10, 'Name': 'Норвежских крон', 'Value': 84.071, 'Previous': 83.7243}, 'PLN': {'ID': 'R01565', 'NumCode': '985', 'CharCode': 'PLN', 'Nominal': 1, 'Name': 'Польский злотый', 'Value': 20.0742, 'Previous': 19.9779}, 'RON': {'ID': 'R01585F', 'NumCode': '946', 'CharCode': 'RON', 'Nominal': 1, 'Name': 'Румынский лей', 'Value': 18.3164, 'Previous': 18.1981}, 'XDR': {'ID': 'R01589', 'NumCode': '960', 'CharCode': 'XDR', 'Nominal': 1, 'Name': 'СДР (специальные права заимствования)', 'Value': 105.6599, 'Previous': 104.6112}, 'SGD': {'ID': 'R01625', 'NumCode': '702', 'CharCode': 'SGD', 'Nominal': 1, 'Name': 'Сингапурский доллар', 'Value': 55.0276, 'Previous': 54.6722}, 'TJS': {'ID': 'R01670', 'NumCode': '972', 'CharCode': 'TJS', 'Nominal': 10, 'Name': 'Таджикских сомони', 'Value': 64.8524, 'Previous': 64.3807}, 'TRY': {'ID': 'R01700J', 'NumCode': '949', 'CharCode': 'TRY', 'Nominal': 10, 'Name': 'Турецких лир', 'Value': 93.5812, 'Previous': 91.9115}, 'TMT': {'ID': 'R01710A', 'NumCode': '934', 'CharCode': 'TMT', 'Nominal': 1, 'Name': 'Новый туркменский манат', 'Value': 21.0144, 'Previous': 20.8662}, 'UZS': {'ID': ' ...

# %%
currencies['Valute']['KZT']
# Out:
# {'ID': 'R01335',
#  'NumCode': '398',
#  'CharCode': 'KZT',
#  'Nominal': 100,
#  'Name': 'Казахстанских тенге',
#  'Value': 17.4832,
#  'Previous': 17.4209}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %%
def exchange_rates(currency, format='full'):    
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'  
    response = requests.get(url).json()['Valute']    
    data = response[currency]     
    if format == 'full':    
        return data      
    elif format == 'value':    
        return data['Value']

# %%
def currency_name(id):    
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'  
    response = requests.get(url).json()['Valute']
    for val in response.keys():
        if response[val]['ID']==id:
            return response[val]['Name']

# %%
currency_name('R01700J')
# Out:
# 'Турецких лир'

# %% [markdown]
# part 2 - HTML

# %%
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   
  
response = requests.get(url)  
  
# Убедимся, что мы успешно получили ответ     
print(response.status_code)    
# => 200   
  
# Выведем полученные данные    
print(response.text)
# Out:
# 200
# <!doctype html>
# <html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#
#     <link rel="canonical" href="https://nplus1.ru/news/2019/06/04/slothbot" />
#
#         <title>Робота-ленивца научили лазать по паутине из тросов</title>
#
#     	    <meta itemprop="datePublished" content="2019-06-04"/>
#
# 	    <meta name="mediator_author" content="Григорий Копиев"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2019/06/04/slothbot/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Он сам добывает энергию с помощью солнечных панелей" />
#
#         <meta name="author" content="Григорий Копиев" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2019/06/04/slothbot" />
#         <meta property="og:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#         <meta name="twitter:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1607011815">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1603187018">
#
#     <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2019/06/04/slothbot"},"headline":"Робота-ленивца научили лазать по паутине из тросов","description":"Он сам добывает энергию с помощью солнечных панелей","image":"https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg","author":{"@type":"Person","name":"Григорий Копиев"},"publisher":{"@type":"Organization","name":"N+1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2019-06-04"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" class="_inner  ">
#
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
# <div class="thx-rospechat">Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)</div>
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: Верхняя перетяжка 100%-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_15000335664353901"></div>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 248569,
#         containerId: 'adfox_15000335664353901',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fqtd',
#             puid1: ''
#         }
#     });
# </script>
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#                 </li>
#                             <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="explainatorium">
#             <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#         </li>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2020/12/11/chaos-making-a-new-science" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/12/11/chaos-making-a-new-science" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Джеймс Глик &laquo;Хаос. Создание новой науки&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/12/04/a-world-without-work" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дэниел Сасскинд &laquo;Будущее без работы. Технологии, автоматизация и стоит ли их бояться&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/12/02/december-2020-observations" class="container-link">
#                     <div class="heading"><span>Космические дневники</span></div>
#                     <div class="link"><span>Что наблюдать на небе в декабре</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/12/01/to-ISS-or-not" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Жизнь после МКС: куда летать космонавтам с 2025 года?</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/12/02/explaining-science" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Игорь Иванов &laquo;Объясняя науку: Руководство для авторов научно-популярных текстов&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/11/30/the-moon-a-history-for-the-future" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Оливер Мортон &laquo;Луна. История будущего&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/material/2020/03/02/second-moon" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Когда астероид не совсем астероид</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/11/27/food-for-joy" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Елена Мотова &laquo;Еда для радости. Записки диетолога&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/11/26/lost-in-math" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Сабина Хоссенфельдер &laquo;Уродливая Вселенная: как поиски красоты заводят физиков в тупик&raquo;</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2020/12/14/rethinking-consciousness" class="container-link active">
#         	        	<div class="heading"><span>Книжная полка</span></div>
#             	    	<div class="link"><span>&laquo;Наука сознания. Современная теория субъективного опыта&raquo; Майкл Грациано</span></div>
# 		            </a>
# 	                                </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="20774" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="robots-drones" href="/rubric/robots-drones">Роботы и дроны</a>
#                                             </p>
#         <p class="table">
#             <a href="/news/2019/06/04">
#                 <time itemprop="datePublished" content="2019-06-04" data-unix="1559662033">
#                     <span>18:27</span>
#                     <span>04 Июнь 2019</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/2.2">
#                 <span>Сложность</span>
#                 <span class="difficult-value">2.2</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Григорий Копиев';
#         _dlData.custom_difficult = '2.2';
#         _dlData.custom_rubric.push('Роботы и дроны');
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Робота-ленивца научили лазать по паутине из тросов</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg"/>
#                                                                 <figcaption>
#                                     <p class="title"></p>
#                                     <p class="credits">Allison Carter, Georgia Tech</p>
#                                 </figcaption>
#                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Американские инженеры разработали робота-ленивца, способного лазать по&nbsp;тросам и&nbsp;перемещаться с&nbsp;одного троса на&nbsp;другой. Благодаря относительно малому потреблению энергии и&nbsp;использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы <a href="https://ieeexplore.ieee.org/document/8642808" target="_blank" rel="nofollow">статьи</a>, представленной на&nbsp;конференции ICRA 2019.</p>
# <p>Создание роботов, способных лазать по&nbsp;тросам&nbsp;— важная технологическая задача, наработки из&nbsp;которой потенциально применимы во&nbsp;многих областях. К&nbsp;примеру, в&nbsp;2016 году в&nbsp;России <a href="https://nplus1.ru/news/2016/09/28/robot" target="_blank">создали</a> робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на&nbsp;грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и&nbsp;осматривает&nbsp;их. Кроме того, потенциально таких роботов можно применять для исследований в&nbsp;густых лесах, в&nbsp;которых ветки соседних деревьев соприкасаются.</p>
# <p>Инженеры из&nbsp;Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и&nbsp;решили создать энергоэффективного робота, на&nbsp;основе которого можно было&nbsp;бы создать робота, способного лазать по&nbsp;веткам. Робот состоит из&nbsp;двух частей и передвигается благодаря колесу в&nbsp;каждой части, соприкасающемуся с&nbsp;тросом.<br></p>
# <p><iframe frameborder="0" src="//www.youtube.com/embed/Sx-WL6BIK3s" width="620" height="349" allowfullscreen="true" class="embed-responsive-item"></iframe><br></p>
# <p>Кроме того, в&nbsp;каждой части робота есть две полноценные шестерни и&nbsp;две связанные с&nbsp;ними, но&nbsp;с&nbsp;вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не&nbsp;мог выйти за&nbsp;ее&nbsp;пределы. Если&nbsp;же роботу необходимо перейти на&nbsp;смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в&nbsp;петле, соединяющей две части.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Компоненты одной из двух частей робота</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а&nbsp;также две солнечные панели, располагающиеся по&nbsp;бокам одной из&nbsp;частей. Разработчики отмечают, что благодаря применению колес для движения по&nbsp;тросам, а&nbsp;также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по&nbsp;тросам.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Механизм блокировки троса</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по&nbsp;тросам. Пользователь может указать точку, за&nbsp;которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до&nbsp;наиболее близкой к заданной точке наблюдательной позиции.</p>
# <p>Ранее инженеры из&nbsp;Технологического института Джорджии <a href="https://nplus1.ru/news/2017/04/13/tarzan" target="_blank" title="Link: https://nplus1.ru/news/2017/04/13/tarzan">создали</a> другого робота-ленивца для работы на&nbsp;тросе. Он&nbsp;так&nbsp;же состоит из&nbsp;двух частей, но&nbsp;имеет совершенно другую конструкцию и&nbsp;принцип работы. Он&nbsp;способен зацепляться концом одной части за&nbsp;трос и&nbsp;раскачивать другую, чтобы затем зацепиться&nbsp;ей. После этого он&nbsp;может отпустить первую часть и&nbsp;снова начать раскачиваться для того, чтобы двигаться дальше.<br></p>
# <p><i>Григорий Копиев</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                 <meter class="top"></meter>
#                                         <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/16/haya-2-chamber-a" data-id="27498" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2020/12/15/36653eb59c1b6499b041e035ea1a4042.jpg"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2020-12-16">08:06</span>
#                         </div>
#                         <h3>Ученые достали первую партию грунта астероида Рюгу</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/15/weird-dinosaur" data-id="27495" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-12-15">вчера</span>
#                 </div>
#
#                                     <h3>Бразильский динозавр отрастил перьевой гребень и по паре шипов на плечах</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/15/MXene-hat" data-id="27490" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-12-15">вчера</span>
#                 </div>
#
#                                     <h3>Максен из карбида титана превратил ткань в клетку Фарадея</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/15/solar-skin" data-id="27491" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-12-15">вчера</span>
#                 </div>
#
#                                     <h3>Роборуку научили чувствовать предметы с помощью солнечных панелей</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/15/monogls-and-climate" data-id="27497" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-12-15">вчера</span>
#                 </div>
#
#                                     <h3>Изменение климата поспособствовало разрушению ирригационных систем в средневековой Средней Азии</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/15/gateway" data-id="27487" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/12/15/a7ff0a677bfba618002c9408dc94539c.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Американцы испытали шлюз обмена данными для истребителей и беспилотных ведомых</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/15/weird-dinosaur" data-id="27495" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/12/15/b27e43179ae0945a4c66cde6c2a5e648.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Бразильский динозавр отрастил перьевой гребень и по паре шипов на плечах</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/12/15/haya-2-ryugu-sample" data-id="27485" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/12/14/3769bab3bf8e7d7a6abb046aae89d4d6.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Астрономы показали грунт астероида Рюгу</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2020/12/10/4ed338343299594a6944c792092861cb.gif" style=background-image:url(https://nplus1.ru/images/2020/12/10/7656ba631bb1f650b9a3c01ae7932bc5.gif)>
#
#     <a href="/material/2020/12/11/blood-type-and-covid" data-id="27431" >
#         <div class="caption">
#                                                                                     <h3>Время первой</h3>
#                     <p class="subtitle">Как группа крови связана с уязвимостью перед коронавирусом</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/biology">Биология</a>
#             </li>
#                                     <li>
#                 <a class="link-theme" href="/theme/coronavirus-history">Коронавирусные хроники</a>
#             </li>
#                     </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="73JdtFfOlPKdb5brjyDHMIFjtpCHJVJAbvh5Rtq7">
#         <input type="hidden" name="id_news" value="20774">
#         <input type="hidden" name="id_author" value="102">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="73JdtFfOlPKdb5brjyDHMIFjtpCHJVJAbvh5Rtq7">
#         <input type="hidden" name="id_news" value="20774">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/14/molecularfermigas">Газ полярных молекул охладили ниже температуры Ферми</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/10/nucleon-hyperon-interaction">На БАК измерили сильное взаимодействие между протонами и редкими гиперонами</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/07/photonquantumadvantage">Квантовое превосходство впервые продемонстрировали на фотонном процессоре</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2020/12/10/alphafold-wat">Гадание на белковой гуще</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/14/are-you-driverless">Ориентация сенсор </a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2020/12/11/blood-type-and-covid">Время первой</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/08/dirty-pandas">Панды обмазались конским навозом в холодную погоду</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/14/iceberg-lettuce">Транспозон на седьмой хромосоме помог салату &laquo;айсберг&raquo; сформировать кочаны</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/15/MXene-hat">Максен из карбида титана превратил ткань в клетку Фарадея</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">4.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/12/10/origin-of-pterosaur">У птерозавров нашлись нелетающие родственники</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2020 N+1 Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
# <script type="text/javascript" async src="https://relap.io/api/v6/head.js?token=sTVMyshMYp9i7-rv"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1592278962"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# part 3 - Beutiful Soup

# %%
from bs4 import BeautifulSoup

# %%
# Получаем данные   
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   
response = requests.get(url)

# %%
# Теперь создадим объект BeautifulSoup, указывая html парсер    
page = BeautifulSoup(response.text, 'html.parser')

# %%
# Для начала получим title, отображающийся на закладках браузера    
print(page.title)
# Out:
# <title>Робота-ленивца научили лазать по паутине из тросов</title>

# %%
page.title.text
# Out:
# 'Робота-ленивца научили лазать по паутине из тросов'

# %%
print(page.find('h1').text)
# Out:
# Робота-ленивца научили лазать по паутине из тросов

# %%
print(page.find('time').text)
# Out:
# 18:27
# 04 Июнь 2019

# %%
pin_floid_url = 'https://ru.wikipedia.org/wiki/Pink_Floyd'
pin_floid_response = requests.get(pin_floid_url)

# %%
pin_floid_page = BeautifulSoup(pin_floid_response.text, 'html.parser')

# %%
print(pin_floid_page.find('h1').text)
# Out:
# Pink Floyd

# %%
def wiki_header(url):
    response = requests.get(url)
    fpage = BeautifulSoup(response.text, 'html.parser')
    #return page.title.text
    return fpage.find('h1').text

# %%
wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# Out:
# 'Operating system'

# %% [markdown]
# Больше данных (более сложные кейсы)

# %%
print(page.find('div').text)
# Out:
# Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)

# %%
print(page.find('div', class_='body').text)
# Out:
# Allison Carter, Georgia Tech
#
#
#
#
#
# Американские инженеры разработали робота-ленивца, способного лазать по тросам и перемещаться с одного троса на другой. Благодаря относительно малому потреблению энергии и использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы статьи, представленной на конференции ICRA 2019.
# Создание роботов, способных лазать по тросам — важная технологическая задача, наработки из которой потенциально применимы во многих областях. К примеру, в 2016 году в России создали робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и осматривает их. Кроме того, потенциально таких роботов можно применять для исследований в густых лесах, в которых ветки соседних деревьев соприкасаются.
# Инженеры из Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и решили создать энергоэффективного робота, на основе которого можно было бы создать робота, способного лазать по веткам. Робот состоит из двух частей и передвигается благодаря колесу в каждой части, соприкасающемуся с тросом.
#
# Кроме того, в каждой части робота есть две полноценные шестерни и две связанные с ними, но с вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не мог выйти за ее пределы. Если же роботу необходимо перейти на смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в петле, соединяющей две части.
#
#
#
#
#
#
#
#
#
# Компоненты одной из двух частей робота
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а также две солнечные панели, располагающиеся по бокам одной из частей. Разработчики отмечают, что благодаря применению колес для движения по тросам, а также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по тросам.
#
#
#
#
#
#
#
#
#
# Механизм блокировки троса
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по тросам. Пользователь может указать точку, за которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до наиболее близкой к заданной точке наблюдательной позиции.
# Ранее инженеры из Технологического института Джорджии создали другого робота-ленивца для работы на тросе. Он так же состоит из двух частей, но имеет совершенно другую конструкцию и принцип работы. Он способен зацепляться концом одной части за трос и раскачивать другую, чтобы затем зацепиться ей. После этого он может отпустить первую часть и снова начать раскачиваться для того, чтобы двигаться дальше.
# Григорий Копиев

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages'  
  
response = requests.get(url)  
page = BeautifulSoup(response.text, 'html.parser')  
page.find('a')
# Out:
# <a id="top"></a>

# %%
links = page.find_all('a')  
# Посмотрим, сколько всего мы получили  
print(len(links))
  
# Посмотрим на некоторые из ссылок  
print([link.text for link in links[500:510]])
# Out:
# 903
# ['Perl', 'PDL', 'Pharo', 'PHP', 'Pico', 'Picolisp', 'Pict', 'Pike', 'PILOT', 'Pipelines']

# %%
# Получаем все элементы с тегом 'div' и классом 'div-col'  
all_blocks = page.find_all('div', class_='div-col')  
for block in all_blocks[0:9]:
    print(block.text)
# Выбираем первый по счету блок  
first_block = all_blocks[0]
print(first_block.text)

# Берём оттуда ссылки (ограничимся первыми десятью)
links = first_block.find_all('a')
print([link.text for link in links[:10]])
# Out:
# A.NET
# A-0 System
# A+
# ABAP
# ABC
# ABC ALGOL
# ACC
# Accent
# Ace DASL (Distributed Application Specification Language)
# Action!
# ActionScript
# Actor
# Ada
# Adenine
# AdvPL
# Agda
# Agilent VEE
# Agora
# AIMMS
# Aldor
# Alef
# ALF
# ALGOL 58
# ALGOL 60
# ALGOL 68
# ALGOL W
# Alice
# Alma-0
# AmbientTalk
# Amiga E
# AMOS
# AMPL
# AngelScript
# Apache Pig latin
# Apex
# APL
# App Inventor for Android's visual block language
# AppleScript
# APT
# Arc
# ARexx
# Argus
# Assembly language
# AutoHotkey
# AutoIt
# AutoLISP / Visual LISP
# Averest
# AWK
# Axum
#
#
# B
# Babbage
# Ballerina
# Bash
# BASIC
# Batch file (Windows/MS-DOS)
# bc
# BCPL
# BeanShell
# Bertrand
# BETA
# BLISS
# Blockly
# BlooP
# Boo
# Boomerang
# Bosque
#
#
# C – ISO/IEC 9899
# C-- (C minus minus)
# C++ (C plus plus) – ISO/IEC 14882
# C*
# C# (C sharp) – ISO/IEC 23270
# C/AL
# Caché ObjectScript
# C Shell (csh)
# Caml
# Cayenne
# CDuce
# Cecil
# Cesil
# Céu
# Ceylon
# CFEngine
# Cg
# Ch
# Chapel
# Charm
# CHILL
# CHIP-8
# chomski
# ChucK
# Cilk
# CL (IBM)
# Claire
# Clarion
# Clean
# Clipper
# CLIPS
# CLIST
# Clojure
# CLU
# CMS-2
# COBOL – ISO/IEC 1989
# CobolScript – COBOL Scripting language
# Cobra
# CoffeeScript
# ColdFusion
# COMAL
# Combined Programming Language (CPL)
# COMIT
# Common Intermediate Language (CIL)
# Common Lisp (also known as CL)
# COMPASS
# Component Pascal
# Constraint Handling Rules (CHR)
# COMTRAN
# Cool
# Coq
# Coral 66
# CorVision
# COWSEL
# CPL
# Cryptol
# Crystal
# Csound
# Cuneiform
# Curl
# Curry
# Cybil
# Cyclone
# Cypher Query Language
# Cython
# CEEMAC
#
#
# D
# Dart
# Darwin
# DataFlex
# Datalog
# DATATRIEVE
# dBase
# dc
# DCL
# Delphi
# DinkC
# DIBOL
# Dog
# Draco
# DRAKON
# Dylan
# DYNAMO
# DAX (Data Analysis Expressions)
#
#
# E
# Ease
# Easy PL/I
# EASYTRIEVE PLUS
# eC
# ECMAScript
# Edinburgh IMP
# EGL
# Eiffel
# ELAN
# Elixir
# Elm
# Emacs Lisp
# Emerald
# Epigram
# EPL (Easy Programming Language)
# EPL (Eltron Programming Language)
# Erlang
# es
# Escher
# ESPOL
# Esterel
# Etoys
# Euclid
# Euler
# Euphoria
# EusLisp Robot Programming Language
# CMS EXEC (EXEC)
# EXEC 2
# Executable UML
# Ezhil
#
#
# F
# F#
# F*
# Factor
# Fantom
# FAUST
# FFP
# fish
# Fjölnir
# FL
# Flavors
# Flex
# FlooP
# FLOW-MATIC
# FOCAL
# FOCUS
# FOIL
# FORMAC
# @Formula
# Forth
# Fortran – ISO/IEC 1539
# Fortress
# FP
# Franz Lisp
# FreeBasic
# Futhark
# F-Script
#
#
# Game Maker Language (Scripting language)
# GameMonkey Script
# GAMS
# GAP
# G-code
# GDScript
# Genie
# GDL
# GEORGE
# GLSL
# GNU E
# GNU Guile
# Go
# Go!
# GOAL
# Gödel
# Golo
# GOM (Good Old Mad)
# Google Apps Script
# Gosu
# GOTRAN
# GPSS
# GraphTalk
# GRASS
# Grasshopper
# Groovy
#
#
# Hack
# HAGGIS
# HAL/S
# Halide (programming language)
# Hamilton C shell
# Harbour
# Hartmann pipelines
# Haskell
# Haxe
# Hermes
# High Level Assembly
# HLSL
# Hollywood
# HolyC
# Hop
# Hopscotch
# Hope
# Hugo
# Hume
# HyperTalk
#
#
# Io
# Icon
# IBM Basic assembly language
# IBM HAScript
# IBM Informix-4GL
# IBM RPG
# IDL
# Idris
# Inform
#
#
# A.NET
# A-0 System
# A+
# ABAP
# ABC
# ABC ALGOL
# ACC
# Accent
# Ace DASL (Distributed Application Specification Language)
# Action!
# ActionScript
# Actor
# Ada
# Adenine
# AdvPL
# Agda
# Agilent VEE
# Agora
# AIMMS
# Aldor
# Alef
# ALF
# ALGOL 58
# ALGOL 60
# ALGOL 68
# ALGOL W
# Alice
# Alma-0
# AmbientTalk
# Amiga E
# AMOS
# AMPL
# AngelScript
# Apache Pig latin
# Apex
# APL
# App Inventor for Android's visual block language
# AppleScript
# APT
# Arc
# ARexx
# Argus
# Assembly language
# AutoHotkey
# AutoIt
# AutoLISP / Visual LISP
# Averest
# AWK
# Axum
#
# ['A.NET', 'A-0 System', 'A+', 'ABAP', 'ABC', 'ABC ALGOL', 'ACC', 'Accent', 'Ace DASL (Distributed Application Specification Language)', 'Action!']

# %%
url = 'https://www.kinopoisk.ru/film/42326/'  
  
response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})  
page = BeautifulSoup(response.text, 'html.parser') 

print(page.find('ul', class_= 'styles_list__I97eu'))

# actors_list = page.find('ul', class_= 'styles_list__I97eu')
# print(len(actors_list))
# Out:
# <ul class="styles_list__I97eu"><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/102198/" itemprop="actor">Мария Виноградова</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/122798/" itemprop="actor">Олег Табаков</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/261607/" itemprop="actor">Лев Дуров</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/273117/" itemprop="actor">Борис Новиков</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/277168/" itemprop="actor">Герман Качин</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/245645/" itemprop="actor">Валентина Талызина</a></li></ul>

# %%
print(actors_list)
# Out:
# <ul class="styles_list__I97eu"><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/102198/" itemprop="actor">Мария Виноградова</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/122798/" itemprop="actor">Олег Табаков</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/261607/" itemprop="actor">Лев Дуров</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/273117/" itemprop="actor">Борис Новиков</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/277168/" itemprop="actor">Герман Качин</a></li><li class="styles_root__-coRa styles_rootInLight__33a_D" data-tid="615a7f9d"><a class="styles_link__1dkjp" href="/name/245645/" itemprop="actor">Валентина Талызина</a></li></ul>

# %%
print([link.text for link in actors_list])
# Out:
# ['Мария Виноградова', 'Олег Табаков', 'Лев Дуров', 'Борис Новиков', 'Герман Качин', 'Валентина Талызина']

# %%
def get_actors(url):
    response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    page = BeautifulSoup(response.text, 'html.parser')  
    actors_list = page.find('ul', class_= 'styles_list__I97eu')
    return [item.text for item in actors_list]

# %%
get_actors('https://www.kinopoisk.ru/film/42326/')
# Out:
# ['Мария Виноградова',
#  'Олег Табаков',
#  'Лев Дуров',
#  'Борис Новиков',
#  'Герман Качин',
#  'Валентина Талызина']

# %%
get_actors('https://www.kinopoisk.ru/film/326/')
# Out:
# ['Тим Роббинс',
#  'Морган Фриман',
#  'Боб Гантон',
#  'Уильям Сэдлер',
#  'Клэнси Браун',
#  'Джил Беллоуз',
#  'Марк Ролстон',
#  'Джеймс Уитмор',
#  'Джеффри ДеМанн',
#  'Ларри Бранденбург']

# %%
import pandas as pd  
url = 'https://www.cbr.ru/key-indicators/'  
# Таблица с драгметаллами оказалась второй по счёту  
pd.read_html(url)[1]
# Out:
#                  0           1
# 0  рублей за грамм  16.12.2020
# 1       Золото  Au    4 354,98
# 2      Серебро  Ag        5633
# 3      Платина  Pt    2 413,27
# 4     Палладий  Pd    5 490,07

# %%
pd.read_html(url)[0]
# Out:
#                  0           1           2
# 0           валюта  15.12.2020  16.12.2020
# 1  Доллар США  USD      729272      734453
# 2        Евро  EUR      885847      891846

# %%
url = 'https://www.cbr.ru/key-indicators/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')

# %%
all_blocks = soup.find_all('div', class_='key-indicator_content offset-md-2')
# Данные таблицы с драгметаллами находятся во втором блоке
data = all_blocks[1].find('table')

# %%
print(data)
# Out:
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value td-w-13">рублей за грамм</td>
# <td class="value td-w-4 _end">16.12.2020</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Золото</div>
# <div class="col-md-3 offset-md-1 _subinfo">Au</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">4 354,98</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Серебро</div>
# <div class="col-md-3 offset-md-1 _subinfo">Ag</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">56,33</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Платина</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pt</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">2 413,27</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Палладий</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pd</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">5 490,07</td>
# </tr>
# </tbody>
# </table>

# %%
df = pd.read_html(str(data))[0]  
df
# Out:
#                  0           1
# 0  рублей за грамм  16.12.2020
# 1        Золото Au    4 354,98
# 2       Серебро Ag        5633
# 3       Платина Pt    2 413,27
# 4      Палладий Pd    5 490,07

# %%
url = 'https://www.banki.ru/banks/ratings/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')

# %%
all_blocks = soup.find_all('div', class_='layout-column-full')
data = all_blocks[2].find('table')
df = pd.read_html(str(data))[0]

# %%
df
# Out:
#      место                  название банка лицензия №, Регион  \
#      место                  название банка лицензия №, Регион
# 0        1            СберБанк лицензия № 1481, Москва и обл.
# 1        2        ВТБ лицензия № 1000, Санкт-Петербург и обл.
# 2        3          Газпромбанк лицензия № 354, Москва и обл.
# 3        4  Национальный Клиринговый Центр лицензия № 3466...
# 4        5          Альфа-Банк лицензия № 1326, Москва и обл.
# 5        6      Россельхозбанк лицензия № 3349, Москва и обл.
# 6        7  Московский Кредитный Банк лицензия № 1978, Мос...
# 7        8       Банк Открытие лицензия № 2209, Москва и обл.
# 8        9        Совкомбанк лицензия № 963, Костромская обл.
# 9    10 +3         ЮниКредит Банк лицензия № 1, Москва и обл.
# 10   11 −1      Райффайзенбанк лицензия № 3292, Москва и обл.
# 11      12               Траст лицензия № 3279, Москва и обл.
# 12   13 −2             Росбанк лицензия № 2272, Москва и обл.
# 13      14      Россия лицензия № 328, Санкт-Петербург и обл.
# 14      15  Всероссийский Банк Развития Регионов лицензия ...
# 15      16  Санкт-Петербург лицензия № 436, Санкт-Петербур...
# 16      17       Тинькофф Банк лицензия № 2673, Москва и обл.
# 17      18            Ситибанк лицензия № 2557, Москва и обл.
# 18      19                 Ак Барс лицензия № 2590, Татарстан
# 19   20 +1             БМ-Банк лицензия № 2748, Москва и обл.
# 20   21 +2         Новикомбанк лицензия № 2546, Москва и обл.
# 21   22 −2            СМП Банк лицензия № 3368, Москва и обл.
# 22   23 −1          Банк Уралсиб лицензия № 30, Москва и обл.
# 23      24           Почта Банк лицензия № 650, Москва и обл.
# 24      25         Банк ДОМ.РФ лицензия № 2312, Москва и обл.
# 25      26  Московский Областной Банк лицензия № 1751, Мос...
# 26      27  Московский Индустриальный Банк лицензия № 912,...
# 27      28            Пересвет лицензия № 2110, Москва и обл.
# 28      29    Русский Стандарт лицензия № 2289, Москва и обл.
# 29   30 +2                  РНКБ лицензия № 1354, Симферополь
# 30      31        Абсолют Банк лицензия № 2306, Москва и обл.
# 31   32 +2  Уральский Банк Реконструкции и Развития лиценз...
# 32   33 −3  Национальный Расчетный Депозитарий лицензия № ...
# 33   34 +3          Банк Зенит лицензия № 3255, Москва и обл.
# 34      35     Хоум Кредит Банк лицензия № 316, Москва и обл.
# 35      36      Восточный Банк лицензия № 1460, Амурская обл.
# 36   37 +2            ИНГ Банк лицензия № 2495, Москва и обл.
# 37   38 −5         Возрождение лицензия № 1439, Москва и обл.
# 38   39 −1            МТС Банк лицензия № 2268, Москва и обл.
# 39      40      Инвестторгбанк лицензия № 2763, Москва и обл.
# 40   41 +1    Транскапиталбанк лицензия № 2210, Москва и обл.
# 41   42 −1        Росэксимбанк лицензия № 2790, Москва и обл.
# 42      43            ОТП Банк лицензия № 2766, Москва и обл.
# 43      44        Сетелем Банк лицензия № 2168, Москва и обл.
# 44  45 +13           Локо-Банк лицензия № 2707, Москва и обл.
# 45   46 −1    Ренессанс Кредит лицензия № 3354, Москва и обл.
# 46      47     Русфинанс Банк лицензия № 1792, Самарская обл.
# 47   48 −2            МСП Банк лицензия № 3340, Москва и обл.
# 48      49  Азиатско-Тихоокеанский Банк лицензия № 1810, А...
# 49      50            Авангард лицензия № 2879, Москва и обл.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          показатель,  тыс. рублей  \
#    Ноябрь, 2020 Октябрь, 2020 Сентябрь, 2020 Август, 2020 Июль, 2020 Июнь, 2020 Май, 2020 Апрель, 2020 Март, 2020 Февраль, 2020 Январь, 2020 Декабрь, 2019 Ноябрь, 2019 Октябрь, 2019 Сентябрь, 2019 Август, 2019 Июль, 2019 Июнь, 2019 Май, 2019 Апрель, 2019 Март, 2019 Февраль, 2019 Январь, 2019 Декабрь, 2018 Ноябрь, 2018 Октябрь, 2018 Сентябрь, 2018 Август, 2018 Июль, 2018 Июнь, 2018 Май, 2018 Апрель, 2018 Март, 2018 Февраль, 2018 Январь, 2018 Декабрь, 2017 Ноябрь, 2017 Октябрь, 2017 Сентябрь, 2017 Август, 2017 Июль, 2017 Июнь, 2017 Май, 2017 Апрель, 2017 Март, 2017 Февраль, 2017 Январь, 2017 Декабрь, 2016 Ноябрь, 2016 Октябрь, 2016 Сентябрь, 2016 Август, 2016 Июль, 2016 Июнь, 2016 Май, 2016 Апрель, 2016 Март, 2016 Февраль, 2016 Январь, 2016 Декабрь, 2015 Ноябрь, 2015 Октябрь, 2015 Сентябрь, 2015 Август, 2015 Июль, 2015 Июнь, 2015 Май, 2015 Апрель, 2015 Март, 2015 Февраль, 2015 Январь, 2015 Декабрь, 2014 Ноябрь, 2014 Октябрь, 2014 Сентябрь, 2014 Август, 2014 Июль, 2014 Июнь, 2014 Май, 2014 Апрель, 2014 Март, 2014 Февраль, 2014 Январь, 2014 Декабрь, 2013 Ноябрь, 2013 Октябрь, 2013 Сентябрь, 2013 Август, 2013 Июль, 2013 Июнь, 2013 Май, 2013 Апрель, 2013 Март, 2013 Февраль, 2013 Январь, 2013 Декабрь, 2012 Ноябрь, 2012 Октябрь, 2012 Сентябрь, 2012 Август, 2012 Июль, 2012 Июнь, 2012 Май, 2012 Апрель, 2012 Март, 2012 Февраль, 2012 Январь, 2012 Декабрь, 2011 Ноябрь, 2011 Октябрь, 2011 Сентябрь, 2011 Август, 2011 Июль, 2011 Июнь, 2011 Май, 2011 Апрель, 2011 Март, 2011 Февраль, 2011 Январь, 2011 Декабрь, 2010 Ноябрь, 2010 Октябрь, 2010 Сентябрь, 2010 Август, 2010 Июль, 2010 Июнь, 2010 Май, 2010 Апрель, 2010 Март, 2010 Февраль, 2010 Январь, 2010 Декабрь, 2009 Ноябрь, 2009 Октябрь, 2009 Сентябрь, 2009 Август, 2009 Июль, 2009 Июнь, 2009 Май, 2009 Апрель, 2009 Март, 2009 Февраль, 2009 Январь, 2009 Декабрь, 2008 Ноябрь, 2008 Октябрь, 2008 Сентябрь, 2008 Август, 2008 Июль, 2008 Июнь, 2008 Май, 2008 Апрель, 2008 Март, 2008
# 0                                      34 081 375 159
# 1                                      16 520 606 342
# 2                                       7 561 422 252
# 3                                       5 010 835 598
# 4                                       4 553 936 508
# 5                                       3 823 292 449
# 6                                       3 033 659 663
# 7                                       2 932 396 467
# 8                                       1 608 851 564
# 9                                       1 448 216 079
# 10                                      1 437 518 264
# 11                                      1 396 488 228
# 12                                      1 382 394 156
# 13                                      1 058 200 753
# 14                                        910 683 704
# 15                                        777 677 600
# 16                                        774 297 014
# 17                                        717 098 954
# 18                                        638 714 255
# 19                                        617 142 680
# ...
# 43                                        158 899 033
# 44                                        117 365 112
# 45                                        158 439 754
# 46                                        146 464 739
# 47                                        151 018 037
# 48                                        138 758 643
# 49                                        137 079 059
#
#        изменение
#      тыс. рублей        %
# 0   +220 879 424   +0,65%
# 1   +267 702 398   +1,65%
# 2    +50 114 053   +0,67%
# 3    −64 544 622   −1,27%
# 4   +145 596 047   +3,30%
# 5    +32 348 615   +0,85%
# 6    −21 723 889   −0,71%
# 7   +106 517 681   +3,77%
# 8    −24 636 035   −1,51%
# 9   +101 619 066   +7,55%
# 10   −23 307 725   −1,60%
# 11    +2 163 300   +0,16%
# 12   −17 642 527   −1,26%
# 13   −14 245 994   −1,33%
# 14      +781 412   +0,09%
# 15   +15 950 588   +2,09%
# 16   +12 762 616   +1,68%
# 17   +11 349 480   +1,61%
# 18    +9 875 100   +1,57%
# 19   +56 470 169  +10,07%
# 20   +27 693 599   +5,08%
# 21    −7 335 694   −1,27%
# 22    +1 720 100   +0,31%
# 23   −18 295 749   −3,37%
# 24   +17 724 382   +3,55%
# 25      −823 763   −0,17%
# 26    +1 580 408   +0,39%
# 27    −6 838 853   −1,96%
# 28    −8 084 376   −2,43%
# 29      +311 958   +0,11%
# 30    −3 285 094   −1,17%
# 31    +9 958 184   +3,90%
# 32   −39 900 981  −13,49%
# 33    +4 981 332   +2,07%
# 34   −10 573 006   −4,22%
# 35    −5 707 984   −2,33%
# 36    +7 134 291   +3,22%
# 37   −48 585 752  −18,89%
# 38   −21 317 276   −9,50%
# 39    +1 973 465   +1,01%
# 40    +8 843 548   +4,76%
# 41    +2 455 477   +1,30%
# 42      +294 434   +0,18%
# 43    +2 258 468   +1,42%
# 44   +42 675 246  +36,36%
# 45      +141 382   +0,09%
# 46      +759 619   +0,52%
# 47    −7 762 631   −5,14%
# 48      +774 154   +0,56%
# 49    +1 537 605   +1,12%
