# %%
import os
import psycopg2
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:admin@localhost:5432/sms-test2')

# %%
raw_data = pd.read_excel('agsk.xlsx', sheet_name='classif', index_col=None)
raw_data.to_sql('agsk_source1', engine)

# %%
raw_data = pd.read_excel('agsk.xlsx', sheet_name='codes', index_col=None)
raw_data.to_sql('doc_type_source', engine)

# %%
raw_data
# Out:
#     doc_type                           type_name
# 0          1                              кодекс
# 1          2                               закон
# 2          3               технический регламент
# 3          4                     положение (НПА)
# 4          5     стандарт государственной услуги
# 5          6    регламент государственной услуги
# 6          7                             правила
# 7          8                          инструкция
# 8          9                              РДС РК
# 9         10                               СН РК
# 10        11                                  СН
# 11        12                        пособие к СН
# 12        13                                 ВСН
# 13        14                                 МСН
# 14        15                       Пособие к МСН
# 15        16                                СНиП
# 16        17                      пособие к СНиП
# 17        18                               СП РК
# ...

# %%
#raw_data = pd.read_excel('agsk.xlsx', sheet_name='classes', index_col=None)
#raw_data.to_sql('classes_source', engine)
