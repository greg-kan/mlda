# %%
from datetime import datetime

# %%
datetime(year=2015, month=7, day=4)
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
from dateutil import parser

# %%
date = parser.parse("4th of July, 2015")
date
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
date.strftime('%D')
# Out:
# '07/04/15'

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
import numpy as np

# %%
date = np.array('2015-07-04', dtype=np.datetime64)
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#        '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2015-07-04')
# Out:
# numpy.datetime64('2015-07-04')

# %%
np.datetime64('2015-07-04 12:00')
# Out:
# numpy.datetime64('2015-07-04T12:00')

# %%
np.datetime64('2015-07-04 12:59:59.501213141', 'ns')
# Out:
# numpy.datetime64('2015-07-04T12:59:59.501213141')

# %%
import pandas as pd

# %%
date = pd.to_datetime("4th of July, 2015")
date
# Out:
# Timestamp('2015-07-04 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#                '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#                '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
index = pd.DatetimeIndex(['2014-07-04', '2014-08-04',
                          '2015-07-04', '2015-08-04'])
data = pd.Series([0, 1, 2, 3], index=index)
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
data['2014-07-04':'2015-07-04']
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# dtype: int64

# %%
data['2015']
# Out:
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
dates = pd.to_datetime([datetime(2015, 7, 3), '4th of July, 2015',
                       '2015-Jul-6', '07-07-2015', '20150708'])
dates
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D')
# Out:
# PeriodIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#              '2015-07-08'],
#             dtype='period[D]', freq='D')

# %%
dates - dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)

# %%
pd.date_range('2015-07-03', '2015-07-10')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8)
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=25, freq='H')
# Out:
# DatetimeIndex(['2015-07-03 00:00:00', '2015-07-03 01:00:00',
#                '2015-07-03 02:00:00', '2015-07-03 03:00:00',
#                '2015-07-03 04:00:00', '2015-07-03 05:00:00',
#                '2015-07-03 06:00:00', '2015-07-03 07:00:00',
#                '2015-07-03 08:00:00', '2015-07-03 09:00:00',
#                '2015-07-03 10:00:00', '2015-07-03 11:00:00',
#                '2015-07-03 12:00:00', '2015-07-03 13:00:00',
#                '2015-07-03 14:00:00', '2015-07-03 15:00:00',
#                '2015-07-03 16:00:00', '2015-07-03 17:00:00',
#                '2015-07-03 18:00:00', '2015-07-03 19:00:00',
#                '2015-07-03 20:00:00', '2015-07-03 21:00:00',
#                '2015-07-03 22:00:00', '2015-07-03 23:00:00',
#                '2015-07-04 00:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.period_range('2015-07', periods=8, freq='M')
# Out:
# PeriodIndex(['2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#              '2016-01', '2016-02'],
#             dtype='period[M]', freq='M')

# %%
pd.timedelta_range(0, periods=10, freq='H')
# Out:
# TimedeltaIndex(['00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
#                 '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %%
pd.timedelta_range(0, periods=49, freq="0H30T")
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 00:30:00', '0 days 01:00:00',
#                 '0 days 01:30:00', '0 days 02:00:00', '0 days 02:30:00',
#                 '0 days 03:00:00', '0 days 03:30:00', '0 days 04:00:00',
#                 '0 days 04:30:00', '0 days 05:00:00', '0 days 05:30:00',
#                 '0 days 06:00:00', '0 days 06:30:00', '0 days 07:00:00',
#                 '0 days 07:30:00', '0 days 08:00:00', '0 days 08:30:00',
#                 '0 days 09:00:00', '0 days 09:30:00', '0 days 10:00:00',
#                 '0 days 10:30:00', '0 days 11:00:00', '0 days 11:30:00',
#                 '0 days 12:00:00', '0 days 12:30:00', '0 days 13:00:00',
#                 '0 days 13:30:00', '0 days 14:00:00', '0 days 14:30:00',
#                 '0 days 15:00:00', '0 days 15:30:00', '0 days 16:00:00',
#                 '0 days 16:30:00', '0 days 17:00:00', '0 days 17:30:00',
#                 '0 days 18:00:00', '0 days 18:30:00', '0 days 19:00:00',
# ...

# %%
from pandas.tseries.offsets import BDay
pd.date_range('2019-07-04', periods=5, freq=BDay())
# Out:
# DatetimeIndex(['2019-07-04', '2019-07-05', '2019-07-08', '2019-07-09',
#                '2019-07-10'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas_datareader import data

# %%
data = pd.read_csv('Fremont_Bridge_2012_to_present.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge East Sidewalk  \
# Date
# 2015-02-24 02:00:00                           3.0
# 2019-01-01 00:00:00                           0.0
# 2019-01-01 01:00:00                           2.0
# 2016-02-15 00:00:00                           3.0
# 2019-01-01 02:00:00                           1.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2015-02-24 02:00:00                           3.0
# 2019-01-01 00:00:00                           9.0
# 2019-01-01 01:00:00                          22.0
# 2016-02-15 00:00:00                           3.0
# 2019-01-01 02:00:00                          11.0

# %%
data.columns = ['West', 'East']
data['Total'] = data.eval('West + East')

# %%
data.dropna().describe()
# Out:
#                West          East         Total
# count  59079.000000  59079.000000  59079.000000
# mean      52.382539     59.590125    111.972664
# std       67.631882     86.871875    141.984104
# min        0.000000      0.000000      0.000000
# 25%        6.000000      7.000000     15.000000
# 50%       29.000000     29.000000     60.000000
# 75%       70.000000     72.000000    146.000000
# max      698.000000    850.000000   1097.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
data.plot()
plt.ylabel('Количество велосипедов по часам'); # Hourly Bicycle Count

# %%
weekly = data.resample('W').sum()
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Количество велосипедов еженедельно'); # Weekly bicycle count

# %%
daily = data.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':', '--', '-'])
plt.ylabel('mean hourly count'); # Среднее количество по часам

# %%
daily.rolling(50, center=True, win_type='gaussian').sum(std=10).plot(style=[':', '--', '-'])

# %%
by_time = data.groupby(data.index.time).mean()
hourly_ticks = 4 * 60 * 60 * np.arange(6)
by_time.plot(xticks=hourly_ticks, style=[':', '--', '-']);

# %%
by_weekday = data.groupby(data.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':', '--', '-']);

# %%
data.index
# Out:
# DatetimeIndex(['2015-02-24 02:00:00', '2019-01-01 00:00:00',
#                '2019-01-01 01:00:00', '2016-02-15 00:00:00',
#                '2019-01-01 02:00:00', '2019-01-01 03:00:00',
#                '2019-01-01 04:00:00', '2019-01-01 05:00:00',
#                '2019-01-01 06:00:00', '2019-01-01 07:00:00',
#                ...
#                '2017-11-28 19:00:00', '2017-06-20 20:00:00',
#                '2016-04-22 22:00:00', '2015-11-21 16:00:00',
#                '2012-10-17 14:00:00', '2013-12-12 05:00:00',
#                '2013-07-19 21:00:00', '2018-05-18 19:00:00',
#                '2014-12-04 07:00:00', '2013-10-01 04:00:00'],
#               dtype='datetime64[ns]', name='Date', length=59088, freq=None)

# %%
weekend = np.where(data.index.weekday < 5, 'Weekday', 'Weekend')
by_time = data.groupby([weekend, data.index.time]).mean()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.ix['Weekday'].plot(ax=ax[0], title='Weekdays', xticks=hourly_ticks, style=[':', '--', '-'])
by_time.ix['Weekend'].plot(ax=ax[1], title='Weekends', xticks=hourly_ticks, style=[':', '--', '-'])
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
